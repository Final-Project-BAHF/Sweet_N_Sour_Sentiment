# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('../db/sentences_sample.txt',sep='|')
df.head()
# Out:
#      id  sentiment                                           sentence ticker  \
# 0  4065        NaN  Patrik's proven command of this business and t...    UAA
# 1  2730        NaN  We will be at the Jefferies conference, hardwa...   NVDA
# 2  4044        NaN                           [Operator Instructions].    UAA
# 3  1833        NaN  Any update that you can share in terms of mile...     GM
# 4  2721        NaN  With that, let me turn to the outlook for the ...   NVDA
#
#                                           call_title        speaker  \
# 0  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...    Kevin Plank
# 1  NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...  Colette Kress
# 2  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...       Operator
# 3  General Motors Company (NYSE:GM) Q3 2019 Earni...  Itay Michaeli
# 4  NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...  Colette Kress
#
#            call_section
# 0          presentation
# 1          presentation
# 2  operator_instruction
# 3              question
# 4          presentation

# %%
# add new datetime column by parsing the date and time out of the call title

df['call_datetime'] = df['call_title'].apply(lambda x: datetime.strptime(x.split('Conference Call')[1].lstrip()[0:-3],
                                        '%B %d, %Y  %I:%M %p'))
df.head()
# Out:
#      id  sentiment                                           sentence ticker  \
# 0  4065        NaN  Patrik's proven command of this business and t...    UAA
# 1  2730        NaN  We will be at the Jefferies conference, hardwa...   NVDA
# 2  4044        NaN                           [Operator Instructions].    UAA
# 3  1833        NaN  Any update that you can share in terms of mile...     GM
# 4  2721        NaN  With that, let me turn to the outlook for the ...   NVDA
#
#                                           call_title        speaker  \
# 0  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...    Kevin Plank
# 1  NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...  Colette Kress
# 2  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...       Operator
# 3  General Motors Company (NYSE:GM) Q3 2019 Earni...  Itay Michaeli
# 4  NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...  Colette Kress
#
#            call_section       call_datetime
# 0          presentation 2019-11-04 08:30:00
# 1          presentation 2019-08-15 17:30:00
# 2  operator_instruction 2019-11-04 08:30:00
# 3              question 2019-10-29 10:00:00
# 4          presentation 2019-08-15 17:30:00

# %%
# output result back to csv
df.to_csv('')
