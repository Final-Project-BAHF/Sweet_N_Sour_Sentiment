# %% [markdown]
# # Sweet n Sour Sentiment on the Street
# Georgia Tech Data Science Bootcamp - Cohort 6
# Final Project
# Team Members:
# * Joseph Ayala
# * Andrew Behrman
# * Michael Fox
# * Michael Hankinson
#
# ### Regression Analysis
#
# #### This notebook is designed to run a multi-variate regression analysis on the various ticker features and determine which is most influential

# %%
import pandas as pd

# %%
df = pd.read_csv('../db/final_complete_merged_dataset.csv', sep='|')
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'call_datetime', 'Unnamed: 0_x', 'id',
#        'sentiment', 'sentence', 'ticker', 'call_title', 'speaker',
#        'call_section', 'vader_sentiment', 'call_date', 'call_time',
#        'unique_id', 'base_date', 'next_date', 'base_close', 'base_volume',
#        'next_close', 'next_volume', 'Unnamed: 0_y', 'marketCap',
#        'percent_change_price', 'percent_change_volume', 'model_results',
#        'kmeans_cluster'],
#       dtype='object')

# %%
df['binary_price_change'] = df['percent_change_price'].apply(lambda x: 1 if (x > 0) else 0)
df['sentiment'] = df['model_results']
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        call_datetime  Unnamed: 0_x   id  \
# 0           0             0  2019-11-01 10:00:00           457  457
# 1           1             1  2019-11-01 10:00:00           458  458
# 2           2             2  2019-11-01 10:00:00           459  459
# 3           3             3  2019-11-01 10:00:00           460  460
# 4           4             4  2019-11-01 10:00:00           461  461
#
#    sentiment                                           sentence ticker  \
# 0          3   Good morning and welcome to the Dominion Ener...      D
# 1          3  At this time, each of your lines is in a liste...      D
# 2          3  At the conclusion of today’s presentation, we ...      D
# 3          4  [Operator Instructions] I would now like to tu...      D
# 4          3                          Good morning and welcome.      D
#
#                                           call_title       speaker  ...  \
# 0  Dominion Energy, Inc. (NYSE:D) Q3 2019 Earning...      Operator  ...
# 1  Dominion Energy, Inc. (NYSE:D) Q3 2019 Earning...      Operator  ...
# 2  Dominion Energy, Inc. (NYSE:D) Q3 2019 Earning...      Operator  ...
# 3  Dominion Energy, Inc. (NYSE:D) Q3 2019 Earning...      Operator  ...
# 4  Dominion Energy, Inc. (NYSE:D) Q3 2019 Earning...  Steven Ridge  ...
#
#   base_volume  next_close next_volume Unnamed: 0_y    marketCap  \
# 0   2424000.0   83.269997   3169600.0            D  67584167936
# 1   2424000.0   83.269997   3169600.0            D  67584167936
# 2   2424000.0   83.269997   3169600.0            D  67584167936
# 3   2424000.0   83.269997   3169600.0            D  67584167936
# 4   2424000.0   83.269997   3169600.0            D  67584167936
#
#   percent_change_price percent_change_volume  model_results  kmeans_cluster  \
# 0             0.872191             30.759076              3               0
# 1             0.872191             30.759076              3               1
# 2             0.872191             30.759076              3               2
# 3             0.872191             30.759076              4               1
# 4             0.872191             30.759076              3               0
#
#    binary_price_change
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x            id     sentiment  \
# count  42941.000000  42941.000000  42941.000000  42941.000000  42941.000000
# mean   21470.000000  23556.465895  18447.076407  18447.076407      3.077129
# std    12396.143291  16081.709925  12520.269232  12520.269232      0.418220
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%    10735.000000  10735.000000   6440.000000   6440.000000      3.000000
# 50%    21470.000000  21470.000000  17778.000000  17778.000000      3.000000
# 75%    32205.000000  32205.000000  29037.000000  29037.000000      3.000000
# max    42940.000000  64976.000000  40712.000000  40712.000000      5.000000
#
#        vader_sentiment    base_close   base_volume    next_close  \
# count     42941.000000  42941.000000  4.294100e+04  42941.000000
# mean          0.259800    143.517541  6.102612e+06    139.942650
# std           0.330205    265.461199  1.140393e+07    246.591195
# min          -0.949300      9.070000  2.280000e+05     10.110000
# 25%           0.000000     42.650002  1.473700e+06     43.680000
# 50%           0.273200     82.730003  2.525500e+06     84.559998
# 75%           0.493900    141.029999  6.106800e+06    138.119995
# max           0.993000   2012.089966  7.865600e+07   1849.930054
#
#         next_volume     marketCap  percent_change_price  \
# count  4.294100e+04  4.294100e+04          42941.000000
# mean   1.319834e+07  5.101830e+10             -0.341603
# std    2.933328e+07  6.092187e+10              5.707717
# min    4.135000e+05  5.205218e+09            -20.808657
# 25%    2.355400e+06  1.279713e+10             -3.140449
# 50%    4.400500e+06  2.386513e+10              0.439476
# 75%    1.070740e+07  5.688201e+10              2.937574
# max    2.159434e+08  2.962090e+11             13.692753
#
#        percent_change_volume  model_results  kmeans_cluster  \
# count           42941.000000   42941.000000    42941.000000
# mean               98.786692       3.077129        1.053189
# std               127.013049       0.418220        1.498334
# min               -30.405860       1.000000        0.000000
# 25%                30.741410       3.000000        0.000000
# 50%                65.650464       3.000000        0.000000
# 75%               124.076569       3.000000        2.000000
# max               771.327086       5.000000        4.000000
#
#        binary_price_change
# count         42941.000000
# mean              0.539415
# std               0.498450
# min               0.000000
# 25%               0.000000
# 50%               1.000000
# 75%               1.000000
# max               1.000000

# %%
import pylab as pl
df['base_volume'].hist()
pl.title('Count of Sentences vs. Base Volume (Distribution)')
pl.show()
df['marketCap'].hist()
pl.title('Count of Sentences vs. Market Cap (Distribution)')
pl.show()
df['percent_change_price'].hist()
pl.title('Count of Sentences vs. Percent Price Change (Distribution)')
pl.show()

# %%
grouped_df = df.groupby(by=['ticker','call_section']).agg({
    'sentiment' : "mean",
    'vader_sentiment': "mean",
    'kmeans_cluster': "mean",  ### FUTURE: Need to figure out how to get better kmeans cluster for group of sentences
    'marketCap': "mean",
    'base_volume': "mean",
    'percent_change_price': "mean",
    'binary_price_change': "mean"
})
#grouped_df = pd.DataFrame((group['sentiment','vader_sentiment','marketCap','base_volume','percent_change_price',
#                                 'binary_price_change']).mean())

grouped_df.head()
# Out:
#                              sentiment  vader_sentiment  kmeans_cluster  \
# ticker call_section
# AAP    answer                 3.090487         0.227533        1.106729
#        operator_instruction   3.136364         0.070109        0.636364
#        presentation           3.139073         0.435914        0.960265
#        question               3.075472         0.132848        1.270440
# ABBV   answer                 3.093117         0.233434        1.056680
#
#                                 marketCap  base_volume  percent_change_price  \
# ticker call_section
# AAP    answer                 11265734656    1805500.0             -7.510963
#        operator_instruction   11265734656    1805500.0             -7.510963
#        presentation           11265734656    1805500.0             -7.510963
#        question               11265734656    1805500.0             -7.510963
# ABBV   answer                131067805696   10009400.0              2.765552
#
#                              binary_price_change
# ticker call_section
# AAP    answer                                  0
#        operator_instruction                    0
#        presentation                            0
#        question                                0
# ABBV   answer                                  1

# %%
grouped_df = grouped_df.reset_index()
grouped_df.head()
# Out:
#   ticker          call_section  sentiment  vader_sentiment  kmeans_cluster  \
# 0    AAP                answer   3.090487         0.227533        1.106729
# 1    AAP  operator_instruction   3.136364         0.070109        0.636364
# 2    AAP          presentation   3.139073         0.435914        0.960265
# 3    AAP              question   3.075472         0.132848        1.270440
# 4   ABBV                answer   3.093117         0.233434        1.056680
#
#       marketCap  base_volume  percent_change_price  binary_price_change
# 0   11265734656    1805500.0             -7.510963                    0
# 1   11265734656    1805500.0             -7.510963                    0
# 2   11265734656    1805500.0             -7.510963                    0
# 3   11265734656    1805500.0             -7.510963                    0
# 4  131067805696   10009400.0              2.765552                    1

# %%
grouped_df.drop(columns='ticker',inplace=True)
grouped_df['call_section_codes'] = grouped_df['call_section'].astype('category').cat.codes
grouped_df.head()
# Out:
#            call_section  sentiment  vader_sentiment  kmeans_cluster  \
# 0                answer   3.090487         0.227533        1.106729
# 1  operator_instruction   3.136364         0.070109        0.636364
# 2          presentation   3.139073         0.435914        0.960265
# 3              question   3.075472         0.132848        1.270440
# 4                answer   3.093117         0.233434        1.056680
#
#       marketCap  base_volume  percent_change_price  binary_price_change  \
# 0   11265734656    1805500.0             -7.510963                    0
# 1   11265734656    1805500.0             -7.510963                    0
# 2   11265734656    1805500.0             -7.510963                    0
# 3   11265734656    1805500.0             -7.510963                    0
# 4  131067805696   10009400.0              2.765552                    1
#
#    call_section_codes
# 0                   0
# 1                   1
# 2                   2
# 3                   3
# 4                   0

# %%
grouped_df = pd.get_dummies(grouped_df, columns=['call_section'])
grouped_df.head()
# Out:
#    sentiment  vader_sentiment  kmeans_cluster     marketCap  base_volume  \
# 0   3.090487         0.227533        1.106729   11265734656    1805500.0
# 1   3.136364         0.070109        0.636364   11265734656    1805500.0
# 2   3.139073         0.435914        0.960265   11265734656    1805500.0
# 3   3.075472         0.132848        1.270440   11265734656    1805500.0
# 4   3.093117         0.233434        1.056680  131067805696   10009400.0
#
#    percent_change_price  binary_price_change  call_section_codes  \
# 0             -7.510963                    0                   0
# 1             -7.510963                    0                   1
# 2             -7.510963                    0                   2
# 3             -7.510963                    0                   3
# 4              2.765552                    1                   0
#
#    call_section_answer  call_section_operator_instruction  \
# 0                    1                                  0
# 1                    0                                  1
# 2                    0                                  0
# 3                    0                                  0
# 4                    1                                  0
#
#    call_section_presentation  call_section_question
# 0                          0                      0
# 1                          0                      0
# 2                          1                      0
# 3                          0                      1
# 4                          0                      0

# %%
grouped_df['vader_operator'] = grouped_df['call_section_operator_instruction'] * grouped_df['vader_sentiment']
grouped_df['vader_presentation'] = grouped_df['call_section_presentation'] * grouped_df['vader_sentiment']
grouped_df['vader_question'] = grouped_df['call_section_question'] * grouped_df['vader_sentiment']
grouped_df['vader_answer'] = grouped_df['call_section_answer'] * grouped_df['vader_sentiment']

grouped_df['sentiment_operator'] = grouped_df['call_section_operator_instruction'] * grouped_df['sentiment']
grouped_df['sentiment_presentation'] = grouped_df['call_section_presentation'] * grouped_df['sentiment']
grouped_df['sentiment_question'] = grouped_df['call_section_question'] * grouped_df['sentiment']
grouped_df['sentiment_answer'] = grouped_df['call_section_answer'] * grouped_df['sentiment']

grouped_df['kmeans_operator'] = grouped_df['call_section_operator_instruction'] * grouped_df['kmeans_cluster']
grouped_df['kmeans_presentation'] = grouped_df['call_section_presentation'] * grouped_df['kmeans_cluster']
grouped_df['kmeans_question'] = grouped_df['call_section_question'] * grouped_df['kmeans_cluster']
grouped_df['kmeans_answer'] = grouped_df['call_section_answer'] * grouped_df['kmeans_cluster']

grouped_df.head()
# Out:
#    sentiment  vader_sentiment  kmeans_cluster     marketCap  base_volume  \
# 0   3.090487         0.227533        1.106729   11265734656    1805500.0
# 1   3.136364         0.070109        0.636364   11265734656    1805500.0
# 2   3.139073         0.435914        0.960265   11265734656    1805500.0
# 3   3.075472         0.132848        1.270440   11265734656    1805500.0
# 4   3.093117         0.233434        1.056680  131067805696   10009400.0
#
#    percent_change_price  binary_price_change  call_section_codes  \
# 0             -7.510963                    0                   0
# 1             -7.510963                    0                   1
# 2             -7.510963                    0                   2
# 3             -7.510963                    0                   3
# 4              2.765552                    1                   0
#
#    call_section_answer  call_section_operator_instruction  ...  \
# 0                    1                                  0  ...
# 1                    0                                  1  ...
# 2                    0                                  0  ...
# 3                    0                                  0  ...
# 4                    1                                  0  ...
#
#    vader_question  vader_answer  sentiment_operator  sentiment_presentation  \
# 0        0.000000      0.227533            0.000000                0.000000
# 1        0.000000      0.000000            3.136364                0.000000
# 2        0.000000      0.000000            0.000000                3.139073
# 3        0.132848      0.000000            0.000000                0.000000
# 4        0.000000      0.233434            0.000000                0.000000
#
#    sentiment_question  sentiment_answer  kmeans_operator  kmeans_presentation  \
# 0            0.000000          3.090487         0.000000             0.000000
# 1            0.000000          0.000000         0.636364             0.000000
# 2            0.000000          0.000000         0.000000             0.960265
# 3            3.075472          0.000000         0.000000             0.000000
# 4            0.000000          3.093117         0.000000             0.000000
#
#    kmeans_question  kmeans_answer
# 0          0.00000       1.106729
# 1          0.00000       0.000000
# 2          0.00000       0.000000
# 3          1.27044       0.000000
# 4          0.00000       1.056680
#
# [5 rows x 24 columns]

# %%
grouped_df.describe()
# Out:
#         sentiment  vader_sentiment  kmeans_cluster     marketCap  \
# count  325.000000       325.000000      325.000000  3.250000e+02
# mean     3.066220         0.235768        1.057826  4.877430e+10
# std      0.047050         0.080048        0.191062  5.924841e+10
# min      2.884615         0.053386        0.142857  5.205218e+09
# 25%      3.037383         0.180026        0.962500  1.233534e+10
# 50%      3.070707         0.236975        1.056680  2.355240e+10
# 75%      3.095238         0.295556        1.155844  5.599563e+10
# max      3.214286         0.435914        1.958333  2.962090e+11
#
#         base_volume  percent_change_price  binary_price_change  \
# count  3.250000e+02            325.000000           325.000000
# mean   5.659208e+06             -0.177755             0.550769
# std    1.025177e+07              5.685890             0.498183
# min    2.280000e+05            -20.808657             0.000000
# 25%    1.473700e+06             -2.840792             0.000000
# 50%    2.525500e+06              0.580556             1.000000
# 75%    6.038700e+06              3.042750             1.000000
# max    7.865600e+07             13.692753             1.000000
#
#        call_section_codes  call_section_answer  \
# count          325.000000           325.000000
# mean             1.501538             0.249231
# std              1.118378             0.433235
# min              0.000000             0.000000
# 25%              1.000000             0.000000
# 50%              2.000000             0.000000
# 75%              2.000000             0.000000
# max              3.000000             1.000000
#
#        call_section_operator_instruction  ...  vader_question  vader_answer  \
# count                         325.000000  ...      325.000000    325.000000
# mean                            0.249231  ...        0.060768      0.061606
# std                             0.433235  ...        0.108834      0.110976
# min                             0.000000  ...        0.000000      0.000000
# 25%                             0.000000  ...        0.000000      0.000000
# 50%                             0.000000  ...        0.000000      0.000000
# 75%                             0.000000  ...        0.000000      0.000000
# max                             1.000000  ...        0.353182      0.401884
#
#        sentiment_operator  sentiment_presentation  sentiment_question  \
# count          325.000000              325.000000          325.000000
# mean             0.756170                0.776345            0.763557
# std              1.314744                1.338650            1.327411
# min              0.000000                0.000000            0.000000
# 25%              0.000000                0.000000            0.000000
# 50%              0.000000                0.000000            0.000000
# 75%              0.000000                2.985816            0.000000
# max              3.176471                3.214286            3.157143
#
#        sentiment_answer  kmeans_operator  kmeans_presentation  \
# count        325.000000       325.000000           325.000000
# mean           0.770149         0.262132             0.256281
# std            1.338833         0.481035             0.445953
# min            0.000000         0.000000             0.000000
# 25%            0.000000         0.000000             0.000000
# 50%            0.000000         0.000000             0.000000
# 75%            0.000000         0.000000             0.747475
# max            3.190476         1.958333             1.326733
#
#        kmeans_question  kmeans_answer
# count       325.000000     325.000000
# mean          0.279532       0.259880
# std           0.491775       0.453771
# min           0.000000       0.000000
# 25%           0.000000       0.000000
# 50%           0.000000       0.000000
# 75%           0.000000       0.000000
# max           1.468254       1.242775
#
# [8 rows x 24 columns]

# %%
import pylab as pl
grouped_df.hist()
pl.show()

# %%
grouped_df['marketCap'].hist()

# %%
grouped_df.head()
# Out:
#    sentiment  vader_sentiment  kmeans_cluster     marketCap  base_volume  \
# 0   3.090487         0.227533        1.106729   11265734656    1805500.0
# 1   3.136364         0.070109        0.636364   11265734656    1805500.0
# 2   3.139073         0.435914        0.960265   11265734656    1805500.0
# 3   3.075472         0.132848        1.270440   11265734656    1805500.0
# 4   3.093117         0.233434        1.056680  131067805696   10009400.0
#
#    percent_change_price  binary_price_change  call_section_codes  \
# 0             -7.510963                    0                   0
# 1             -7.510963                    0                   1
# 2             -7.510963                    0                   2
# 3             -7.510963                    0                   3
# 4              2.765552                    1                   0
#
#    call_section_answer  call_section_operator_instruction  ...  \
# 0                    1                                  0  ...
# 1                    0                                  1  ...
# 2                    0                                  0  ...
# 3                    0                                  0  ...
# 4                    1                                  0  ...
#
#    vader_question  vader_answer  sentiment_operator  sentiment_presentation  \
# 0        0.000000      0.227533            0.000000                0.000000
# 1        0.000000      0.000000            3.136364                0.000000
# 2        0.000000      0.000000            0.000000                3.139073
# 3        0.132848      0.000000            0.000000                0.000000
# 4        0.000000      0.233434            0.000000                0.000000
#
#    sentiment_question  sentiment_answer  kmeans_operator  kmeans_presentation  \
# 0            0.000000          3.090487         0.000000             0.000000
# 1            0.000000          0.000000         0.636364             0.000000
# 2            0.000000          0.000000         0.000000             0.960265
# 3            3.075472          0.000000         0.000000             0.000000
# 4            0.000000          3.093117         0.000000             0.000000
#
#    kmeans_question  kmeans_answer
# 0          0.00000       1.106729
# 1          0.00000       0.000000
# 2          0.00000       0.000000
# 3          1.27044       0.000000
# 4          0.00000       1.056680
#
# [5 rows x 24 columns]

# %%
from pandas import DataFrame
from sklearn import linear_model
# train test split
from sklearn.model_selection import train_test_split

X_all = grouped_df.drop(columns=['vader_sentiment','kmeans_cluster','sentiment','percent_change_price','binary_price_change',
                            'call_section_answer','call_section_operator_instruction','call_section_presentation',
                            'vader_sentiment',
                        #   'vader_question', 'vader_answer','vader_operator','vader_presentation',
                        #   'sentiment_question', 'sentiment_answer','sentiment_operator','sentiment_presentation',
                        #    'kmeans_question', 'kmeans_answer','kmeans_operator','kmeans_presentation',
                        #     'base_volume','marketCap',
                             'call_section_codes',
                            'call_section_question']) # here we have variables for multiple regression. 
X_vader = grouped_df.drop(columns=['vader_sentiment','kmeans_cluster','sentiment','percent_change_price','binary_price_change',
                            'call_section_answer','call_section_operator_instruction','call_section_presentation',
                            'vader_sentiment',
                         #  'vader_question', 'vader_answer','vader_operator','vader_presentation',
                           'sentiment_question', 'sentiment_answer','sentiment_operator','sentiment_presentation',
                            'kmeans_question', 'kmeans_answer','kmeans_operator','kmeans_presentation',
                             'base_volume','marketCap',
                             'call_section_codes',
                            'call_section_question']) # here we have variables for multiple regression. 
X_sweet = grouped_df.drop(columns=['vader_sentiment','kmeans_cluster','sentiment','percent_change_price','binary_price_change',
                            'call_section_answer','call_section_operator_instruction','call_section_presentation',
                            'vader_sentiment',
                           'vader_question', 'vader_answer','vader_operator','vader_presentation',
                        #   'sentiment_question', 'sentiment_answer','sentiment_operator','sentiment_presentation',
                            'kmeans_question', 'kmeans_answer','kmeans_operator','kmeans_presentation',
                             'base_volume','marketCap',
                             'call_section_codes',
                            'call_section_question']) # here we have variables for multiple regression. 
X_kmeans = grouped_df.drop(columns=['vader_sentiment','kmeans_cluster','sentiment','percent_change_price','binary_price_change',
                            'call_section_answer','call_section_operator_instruction','call_section_presentation',
                            'vader_sentiment',
                           'vader_question', 'vader_answer','vader_operator','vader_presentation',
                           'sentiment_question', 'sentiment_answer','sentiment_operator','sentiment_presentation',
                        #    'kmeans_question', 'kmeans_answer','kmeans_operator','kmeans_presentation',
                             'base_volume','marketCap',
                             'call_section_codes',
                            'call_section_question']) # here we have variables for multiple regression. 
X_mkt = grouped_df.drop(columns=['vader_sentiment','kmeans_cluster','sentiment','percent_change_price','binary_price_change',
                            'call_section_answer','call_section_operator_instruction','call_section_presentation',
                            'vader_sentiment',
                           'vader_question', 'vader_answer','vader_operator','vader_presentation',
                           'sentiment_question', 'sentiment_answer','sentiment_operator','sentiment_presentation',
                            'kmeans_question', 'kmeans_answer','kmeans_operator','kmeans_presentation',
                        #     'base_volume','marketCap',
                             'call_section_codes',
                            'call_section_question']) # here we have variables for multiple regression. 
X = [X_all, X_vader, X_sweet, X_kmeans, X_mkt]
#Y = grouped_df['percent_change_price']
Y = grouped_df['binary_price_change']

for x_group in X:
    
    X_train, X_test, y_train, y_test = train_test_split(x_group, Y, random_state=1)

    # with sklearn
    #regr = linear_model.LinearRegression()
    regr = linear_model.LogisticRegression()
    regr.fit(X_train, y_train)

    print('*****')
    print('sklearn results:')
    print('Intercept: \n', regr.intercept_)
    print('Coefficients: \n', regr.coef_)
    print('*****')
    print(f'Logistic Regression Accuracy: {regr.score(X_test,y_test)}')
# Out:
# *****
# sklearn results:
# Intercept:
#  [-3.05869831e-23]
# Coefficients:
#  [[ 5.10917813e-12  8.60451585e-16  5.37482921e-24 -1.38926668e-23
#   -2.42669196e-24 -1.35852747e-24  1.03491283e-22 -1.22103228e-22
#   -4.90761242e-23 -2.73556571e-23  8.26735064e-23 -4.19334454e-23
#   -2.65662548e-23 -8.04075649e-24]]
# *****
# Logistic Regression Accuracy: 0.6219512195121951
# *****
# sklearn results:
# Intercept:
#  [0.12430267]
# Coefficients:
#  [[ 0.35827403 -0.43274174 -0.02155559 -0.02835151]]
# *****
# Logistic Regression Accuracy: 0.5365853658536586
# *****
# sklearn results:
# Intercept:
#  [0.02351349]
# Coefficients:
#  [[ 0.09839932 -0.03056052  0.0148519   0.021891  ]]
# *****
# Logistic Regression Accuracy: 0.5
# *****
# sklearn results:
# Intercept:
#  [-0.32808749]
# Coefficients:
#  [[0.73670815 0.22679155 0.2960592  0.38455357]]
# *****
# Logistic Regression Accuracy: 0.43902439024390244
# *****
# sklearn results:
# Intercept:
#  [-3.05869831e-23]
# Coefficients:
#  [[5.10917813e-12 8.60451585e-16]]
# *****
# Logistic Regression Accuracy: 0.6219512195121951
# /Users/i817245/anaconda3/envs/gtfinalproj/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/i817245/anaconda3/envs/gtfinalproj/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/i817245/anaconda3/envs/gtfinalproj/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/i817245/anaconda3/envs/gtfinalproj/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/i817245/anaconda3/envs/gtfinalproj/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

df_logit_results = pd.DataFrame(columns=['Variable Set','Pseudo r^2','LLR p-value'])
var_sets = ['All', 'Vader Sentiment', 'Sweet Sentiment', 'Kmeans', 'Mkt Vars']
for idx,x_group in enumerate(X):
    X_train, X_test, y_train, y_test = train_test_split(x_group, Y, random_state=1)
    print(f'Variable Set: {X_train.columns}')
    # scale data
    X_scaler = StandardScaler().fit(X_train)

    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    logit_model=sm.Logit(y_train, X_train_scaled)
    result=logit_model.fit()
    print('*****')
    
    print(result.summary2())
    

    
    ##Computing false and true positive rates
    fpr, tpr, thresholds =roc_curve(y_test, result.predict(X_test_scaled),drop_intermediate=False)

    plt.figure()
    ##Adding the ROC
    plt.plot(fpr, tpr, color='red',
     lw=2, label='ROC curve')
    ##Random FPR and TPR
    plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--')
    ##Title and label
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC (Receiving Operator Characteristic) curve')
    plt.show()


    # append key figures to results dataframe
    df_logit_results = df_logit_results.append({
        'Variable Set': var_sets[idx],
        'Pseudo r^2': result.prsquared,
        'LLR p-value': result.llr_pvalue
    }, ignore_index=True)
# Out:
# Variable Set: Index(['marketCap', 'base_volume', 'vader_operator', 'vader_presentation',
#        'vader_question', 'vader_answer', 'sentiment_operator',
#        'sentiment_presentation', 'sentiment_question', 'sentiment_answer',
#        'kmeans_operator', 'kmeans_presentation', 'kmeans_question',
#        'kmeans_answer'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.645318
#          Iterations 6
# *****
#                           Results: Logit
# ==================================================================
# Model:              Logit               Pseudo R-squared: 0.067
# Dependent Variable: binary_price_change AIC:              341.6245
# Date:               2019-11-21 02:20    BIC:              390.5273
# No. Observations:   243                 Log-Likelihood:   -156.81
# Df Model:           13                  LL-Null:          -168.09
# Df Residuals:       229                 LLR p-value:      0.047414
# Converged:          1.0000              Scale:            1.0000
# No. Iterations:     6.0000
# ---------------------------------------------------------------------
#         Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------
# x1      0.3481      0.1855     1.8763    0.0606    -0.0155     0.7116
# x2      0.0703      0.1958     0.3590    0.7196    -0.3134     0.4540
# x3     -0.0533      0.4097    -0.1301    0.8964    -0.8564     0.7497
# x4     -0.3137      0.5198    -0.6035    0.5462    -1.3325     0.7051
# x5      0.2549      0.5590     0.4561    0.6483    -0.8406     1.3505
# x6      0.1627      0.5132     0.3170    0.7512    -0.8432     1.1687
# x7      1.5253      4.5685     0.3339    0.7385    -7.4288    10.4794
# x8      3.4038      4.4749     0.7606    0.4469    -5.3669    12.1745
# x9      4.2182      4.7881     0.8810    0.3783    -5.1663    13.6027
# x10     2.2376      4.9470     0.4523    0.6510    -7.4584    11.9336
# x11     1.7485      0.6267     2.7898    0.0053     0.5201     2.9768
# x12    -0.2834      0.9759    -0.2904    0.7715    -2.1961     1.6293
# x13    -1.5274      1.0550    -1.4477    0.1477    -3.5953     0.5404
# x14     0.6678      1.5419     0.4331    0.6649    -2.3543     3.6899
# ==================================================================
# Variable Set: Index(['vader_operator', 'vader_presentation', 'vader_question',
#        'vader_answer'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.690166
#          Iterations 4
# *****
#                           Results: Logit
# ==================================================================
# Model:              Logit               Pseudo R-squared: 0.002
# Dependent Variable: binary_price_change AIC:              343.4205
# Date:               2019-11-21 02:20    BIC:              357.3928
# No. Observations:   243                 Log-Likelihood:   -167.71
# Df Model:           3                   LL-Null:          -168.09
# Df Residuals:       239                 LLR p-value:      0.86062
# Converged:          1.0000              Scale:            1.0000
# No. Iterations:     4.0000
# ---------------------------------------------------------------------
#          Coef.     Std.Err.       z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------
# x1       0.1415      0.2428     0.5828    0.5600    -0.3344    0.6174
# x2      -0.0496      0.2395    -0.2070    0.8360    -0.5190    0.4198
# x3       0.0463      0.2436     0.1899    0.8494    -0.4312    0.5237
# x4       0.0461      0.2479     0.1860    0.8524    -0.4397    0.5320
# ==================================================================
# Variable Set: Index(['sentiment_operator', 'sentiment_presentation', 'sentiment_question',
#        'sentiment_answer'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.690683
#          Iterations 4
# *****
#                           Results: Logit
# ==================================================================
# Model:              Logit               Pseudo R-squared: 0.001
# Dependent Variable: binary_price_change AIC:              343.6718
# Date:               2019-11-21 02:20    BIC:              357.6441
# No. Observations:   243                 Log-Likelihood:   -167.84
# Df Model:           3                   LL-Null:          -168.09
# Df Residuals:       239                 LLR p-value:      0.91848
# Converged:          1.0000              Scale:            1.0000
# No. Iterations:     4.0000
# ---------------------------------------------------------------------
#           Coef.     Std.Err.      z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------
# x1        0.5803      4.2441    0.1367    0.8912    -7.7380    8.8987
# x2        0.3947      4.1000    0.0963    0.9233    -7.6412    8.4307
# x3        0.4650      4.1982    0.1108    0.9118    -7.7633    8.6933
# x4        0.4872      4.3095    0.1130    0.9100    -7.9592    8.9335
# ==================================================================
# Variable Set: Index(['kmeans_operator', 'kmeans_presentation', 'kmeans_question',
#        'kmeans_answer'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.677862
#          Iterations 5
# *****
#                           Results: Logit
# ==================================================================
# Model:              Logit               Pseudo R-squared: 0.020
# Dependent Variable: binary_price_change AIC:              337.4409
# Date:               2019-11-21 02:20    BIC:              351.4132
# No. Observations:   243                 Log-Likelihood:   -164.72
# Df Model:           3                   LL-Null:          -168.09
# Df Residuals:       239                 LLR p-value:      0.080920
# Converged:          1.0000              Scale:            1.0000
# No. Iterations:     5.0000
# ---------------------------------------------------------------------
#           Coef.     Std.Err.      z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------
# x1        0.9004      0.3905    2.3060    0.0211     0.1351    1.6657
# x2        0.6053      0.3719    1.6277    0.1036    -0.1236    1.3342
# x3        0.6684      0.3800    1.7590    0.0786    -0.0764    1.4131
# x4        0.7174      0.3900    1.8394    0.0659    -0.0470    1.4818
# ==================================================================
# Variable Set: Index(['marketCap', 'base_volume'], dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.678278
#          Iterations 5
# *****
#                           Results: Logit
# ==================================================================
# Model:              Logit               Pseudo R-squared: 0.019
# Dependent Variable: binary_price_change AIC:              333.6433
# Date:               2019-11-21 02:20    BIC:              340.6294
# No. Observations:   243                 Log-Likelihood:   -164.82
# Df Model:           1                   LL-Null:          -168.09
# Df Residuals:       241                 LLR p-value:      0.010604
# Converged:          1.0000              Scale:            1.0000
# No. Iterations:     5.0000
# ---------------------------------------------------------------------
#           Coef.     Std.Err.      z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------
# x1        0.3260      0.1761    1.8509    0.0642    -0.0192    0.6713
# x2        0.0816      0.1972    0.4141    0.6788    -0.3048    0.4681
# ==================================================================

# %%
df_logit_results
# Out:
#       Variable Set  Pseudo r^2  LLR p-value
# 0              All    0.067076     0.047414
# 1  Vader Sentiment    0.002241     0.860622
# 2  Sweet Sentiment    0.001493     0.918478
# 3           Kmeans    0.020028     0.080920
# 4         Mkt Vars    0.019426     0.010604

# %%
# append key figures to results dataframe
df_rf_results = pd.DataFrame(columns=['Variable Set','Accuracy'])
    
for idx,x_group in enumerate(X):
    X_train, X_test, y_train, y_test = train_test_split(x_group, Y, random_state=1)

    # try random forest
    from sklearn.ensemble import RandomForestClassifier

    # Instantiate model with 500 decision trees
    rf = RandomForestClassifier(n_estimators = 200, random_state = 1)

    # Train the model on training data
    rf.fit(X_train, y_train)
    
    print('*****')
    print('Random Forest Accuracy of Predicting Positive/Negative price Change: ')
    print(rf.score(X_test, y_test))
    
    feature_importances = zip(X_test.columns, rf.feature_importances_)
    sorted_features = sorted(feature_importances, key=lambda x: x[1],reverse=True)
    print('*****')
    print(sorted_features)
    
    # append key figures to results dataframe
    df_rf_results = df_rf_results.append({
        'Variable Set': var_sets[idx],
        'Accuracy': rf.score(X_test, y_test)
    }, ignore_index=True)
# Out:
# *****
# Random Forest Accuracy of Predicting Positive/Negative price Change:
# 0.6219512195121951
# *****
# [('marketCap', 0.22376904820405444), ('base_volume', 0.22249169317004955), ('kmeans_operator', 0.06080667063075558), ('vader_question', 0.052554920931197915), ('kmeans_answer', 0.05043795381818695), ('vader_answer', 0.04734908114710394), ('vader_operator', 0.046522448317974495), ('kmeans_presentation', 0.046151802663329855), ('vader_presentation', 0.045825563913759734), ('sentiment_answer', 0.045184968219590574), ('kmeans_question', 0.04367470453721931), ('sentiment_presentation', 0.0414840980887597), ('sentiment_question', 0.0373346960105945), ('sentiment_operator', 0.036412350347423496)]
# *****
# Random Forest Accuracy of Predicting Positive/Negative price Change:
# 0.524390243902439
# *****
# [('vader_answer', 0.2680924453387966), ('vader_operator', 0.25577519564965706), ('vader_question', 0.24108884635990177), ('vader_presentation', 0.23504351265164464)]
# *****
# Random Forest Accuracy of Predicting Positive/Negative price Change:
# 0.4878048780487805
# *****
# [('sentiment_answer', 0.28980091501267335), ('sentiment_question', 0.2585435905139739), ('sentiment_presentation', 0.25385931718441723), ('sentiment_operator', 0.19779617728893567)]
# *****
# Random Forest Accuracy of Predicting Positive/Negative price Change:
# 0.4878048780487805
# *****
# [('kmeans_answer', 0.27548633769445396), ('kmeans_question', 0.2451338172771984), ('kmeans_presentation', 0.24278082431515008), ('kmeans_operator', 0.2365990207131976)]
# *****
# Random Forest Accuracy of Predicting Positive/Negative price Change:
# 0.9512195121951219
# *****
# [('base_volume', 0.5101823013660632), ('marketCap', 0.4898176986339368)]

# %%
df_rf_results
# Out:
#       Variable Set  Accuracy
# 0              All  0.621951
# 1  Vader Sentiment  0.524390
# 2  Sweet Sentiment  0.487805
# 3           Kmeans  0.487805
# 4         Mkt Vars  0.951220

# %%
df_rf_results.plot(kind='bar',x='Variable Set',y='Accuracy',title='Random Forest Accuracy')
