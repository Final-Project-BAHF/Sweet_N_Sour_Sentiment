# %% [markdown]
# # Sweet n Sour Sentiment on the Street
# Georgia Tech Data Science Bootcamp - Cohort 6
# Final Project
# Team Members:
# * Joseph Ayala
# * Andrew Behrman
# * Michael Fox
# * Michael Hankinson
#
# ### Transcript Scraper
#
# #### This notebook is designed to scrape the most recent Earnings Call Transcript for each of 100 S&P500 companies, chunk the call into 4 categories (Operator dialogue, Company presentation, Analyst Questions, Company Responses), and produce a dataset of the constituent sentences in each category. It leverages a custom-built API to do the web scraping and data prep before inserting into a MongoDb.

# %%
# Dependencies
import requests
import json
import pandas as pd
import random

# %% [markdown]
# #### Scrape call list from SeekingAlpha website
# Get transcript data for specified tickers
#
# Source: SeekingAlpha.com

# %%
# read in list of tickers
list_tickers = pd.read_csv('../db/hundred_tickers.csv')
list_tickers = list_tickers[77:100]
list_tickers
# Out:
#    ticker
# 77    VAR
# 78    MET
# 79    CAG
# 80    ACN
# 81    DVN
# 82    VTR
# 83    NEM
# 84    NFX
# 85    BAC
# 86   CINF
# 87    MTB
# 88    AVB
# 89   VRSN
# 90    CNP
# 91    KSS
# 92    TWX
# 93   AMAT
# 94    NOV
# 95    LLY
# 96      M
# 97    MAR
# 98    ALK
# 99    PRU

# %% [markdown]
# ##### Iterate through list of tickers, call api for each, and store resulting record to mongodb

# %%
import pymongo
import time

# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define database and collection
db = client.sweet_n_sour
collection = db.many_call_transcripts

# process each ticker
for ticker in list_tickers['ticker']:
    
    try:
        # call api
        response = requests.get(f'http://127.0.0.1:5000/api/get-scripts/{ticker}/1')
        call_dict = response.json()

        ## DEBUG
        #json.dumps(call_dict[0])
        ##

        # store record in mongo
        if len(call_dict) > 0:
            collection.insert_one(call_dict[0])
            print(f'{ticker}: wrote to mongo')
        else:
            print(f'{ticker}: {response.text}')

        # pause few secs between calls
        sleeper = random.choice([1,2,3,4])
        print(f'sleeping {sleeper} seconds...')
        time.sleep(sleeper)
        
    except:
        print(f'{ticker}: caught error, skipping...')
# Out:
# VRTX: wrote to mongo
# sleeping 4 seconds...
# D: wrote to mongo
# sleeping 4 seconds...
# WELL: wrote to mongo
# sleeping 3 seconds...
# ORCL: wrote to mongo
# sleeping 2 seconds...
# NTRS: wrote to mongo
# sleeping 4 seconds...
# RCL: wrote to mongo
# sleeping 1 seconds...
# REG: wrote to mongo
# sleeping 2 seconds...
# EQT: wrote to mongo
# sleeping 1 seconds...
# CFG: wrote to mongo
# sleeping 4 seconds...
# TSN: wrote to mongo
# sleeping 4 seconds...
# DVA: wrote to mongo
# sleeping 3 seconds...
# EVHC: wrote to mongo
# sleeping 3 seconds...
# CRM: wrote to mongo
# sleeping 4 seconds...
# MMC: wrote to mongo
# sleeping 3 seconds...
# BF.B: wrote to mongo
# sleeping 2 seconds...
# UNM: wrote to mongo
# sleeping 3 seconds...
# ADM: wrote to mongo
# sleeping 2 seconds...
# ETR: wrote to mongo
# sleeping 2 seconds...
# SCG: wrote to mongo
# sleeping 2 seconds...
# PX: wrote to mongo
# sleeping 1 seconds...
# GLW: wrote to mongo
# sleeping 3 seconds...
# BKNG: wrote to mongo
# sleeping 1 seconds...
# ROP: wrote to mongo
# sleeping 4 seconds...
# UDR: wrote to mongo
# sleeping 3 seconds...
# MDT: wrote to mongo
# sleeping 2 seconds...
# MSI: wrote to mongo
# sleeping 4 seconds...
# CBRE: wrote to mongo
# sleeping 2 seconds...
# NFLX: wrote to mongo
# sleeping 2 seconds...
# MLM: wrote to mongo
# sleeping 4 seconds...
# ANDV: wrote to mongo
# sleeping 1 seconds...
# AIZ: wrote to mongo
# sleeping 2 seconds...
# CMI: wrote to mongo
# sleeping 4 seconds...
# COF: wrote to mongo
# sleeping 3 seconds...
# APC: wrote to mongo
# sleeping 4 seconds...
# IP: wrote to mongo
# sleeping 3 seconds...
# DE: wrote to mongo
# sleeping 4 seconds...
# KMX: wrote to mongo
# sleeping 2 seconds...
# SEE: wrote to mongo
# sleeping 2 seconds...
# SBUX: wrote to mongo
# sleeping 3 seconds...
# HRL: wrote to mongo
# sleeping 4 seconds...
# JNPR: wrote to mongo
# sleeping 4 seconds...
# AAP: wrote to mongo
# sleeping 2 seconds...
# AEE: wrote to mongo
# sleeping 1 seconds...
# ABT: wrote to mongo
# sleeping 4 seconds...
# MTD: wrote to mongo
# sleeping 3 seconds...
# TRV: wrote to mongo
# sleeping 3 seconds...
# BDX: wrote to mongo
# sleeping 3 seconds...
# PNR: wrote to mongo
# sleeping 2 seconds...
# LYB: wrote to mongo
# sleeping 2 seconds...
# JBHT: wrote to mongo
# sleeping 4 seconds...
# MO: wrote to mongo
# sleeping 2 seconds...
# INCY: wrote to mongo
# sleeping 3 seconds...
# SRCL: wrote to mongo
# sleeping 3 seconds...
# RTN: wrote to mongo
# sleeping 4 seconds...
# DWDP: wrote to mongo
# sleeping 2 seconds...
# AMG: wrote to mongo
# sleeping 3 seconds...
# CCI: wrote to mongo
# sleeping 4 seconds...
# NRG: wrote to mongo
# sleeping 2 seconds...
# VMC: wrote to mongo
# sleeping 4 seconds...
# ESRX: wrote to mongo
# sleeping 3 seconds...
# AMT: wrote to mongo
# sleeping 3 seconds...
# LNC: wrote to mongo
# sleeping 1 seconds...
# XLNX: wrote to mongo
# sleeping 4 seconds...
# CL: wrote to mongo
# sleeping 1 seconds...
# ABBV: wrote to mongo
# sleeping 2 seconds...
# CLX: wrote to mongo
# sleeping 2 seconds...
# XEL: wrote to mongo
# sleeping 4 seconds...
# CMG: wrote to mongo
# sleeping 2 seconds...
# PFG: wrote to mongo
# sleeping 2 seconds...
# FOX: wrote to mongo
# sleeping 3 seconds...
# DUK: wrote to mongo
# sleeping 4 seconds...
# MA: wrote to mongo
# sleeping 3 seconds...
# MOS: wrote to mongo
# sleeping 4 seconds...
# TMK: wrote to mongo
# sleeping 2 seconds...
# HSIC: wrote to mongo
# sleeping 2 seconds...
# EOG: wrote to mongo
# sleeping 4 seconds...
# WMT: wrote to mongo
# sleeping 4 seconds...
# VAR: wrote to mongo
# sleeping 2 seconds...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-fa6014169b01> in <module>
#      15     # call api
#      16     response = requests.get(f'http://127.0.0.1:5000/api/get-scripts/{ticker}/1')
# ---> 17     call_dict = response.json()
#      18
#      19     ## DEBUG
#
# ~/anaconda3/envs/gtfinalproj/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/envs/gtfinalproj/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/envs/gtfinalproj/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/envs/gtfinalproj/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
