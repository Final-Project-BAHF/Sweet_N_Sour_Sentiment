# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import pandas as pd

# %%
df = pd.read_excel("../db/sentence_sample_mh.xlsx",header=1)
df.to_csv("data.csv", sep="|")
dataset1 = pd.read_csv('data.csv', header=None, sep='|')
dataset1
# Out:
#            0     1    2                                                  3  \
# 0        NaN  4065  4.0  Patrik's proven command of this business and t...
# 1        0.0  2730  3.0  We will be at the Jefferies conference, hardwa...
# 2        1.0  4044  3.0                           [Operator Instructions].
# 3        2.0  1833  3.0  Any update that you can share in terms of mile...
# 4        3.0  2721  3.0  With that, let me turn to the outlook for the ...
# 5        4.0  3984  3.0                                   Hope that helps.
# 6        5.0  3929  1.0  Since you're probably wondering and we've talk...
# 7        6.0  1004  3.0  Good morning and welcome to GE's third quarter...
# 8        7.0  2010  2.0  There's no other like one time item or whateve...
# 9        8.0  1042  4.0  We started putting that cash to work, with a $...
# 10       9.0    28  5.0  I’m pleased to announce that carne asada is th...
# 11      10.0  4837  4.0  We have 30.2 million digital active customers ...
# 12      11.0  1563  4.0  So, I think what you see a little bit relative...
# 13      12.0  2226  2.0  I think it is very hard to provide guidance on...
# 14      13.0  4590  3.0                And I believe that we started that.
# 15      14.0   348  3.0   And then on carne asada, if you could help qu...
# 16      15.0  3609  5.0  So the focus that we've put on the customer ex...
# 17      16.0  4820  4.0  Mortgage originations increased $5 billion fro...
# 18      17.0   574  3.0                        Well, that is Customer 360.
# 19      18.0  4004  3.0   Our next question comes from the line of Bria...
# 20      19.0  1995  2.0  From a raw material and tariff perspective to ...
# 21      20.0  3479  4.0                We now cover 80% of our store base.
# 22      21.0  1937  2.0  And don't underestimate the work that we've be...
# 23      22.0  1823  3.0  Can you put the more detail what you thinking ...
# 24      23.0  3266  5.0  Additionally, with the lap of the leadership c...
# 25      24.0  4671  1.0  It's tough getting to $5 billion, I'll tell yo...
# 26      25.0  2480  4.0  But September was an especially strong month f...
# 27      26.0  2581  3.0                                 Your line is open.
# 28      27.0  2293  3.0                        Thanks for all the details.
# 29      28.0  2600  4.0  So again, source transaction was very importan...
# ...      ...   ...  ...                                                ...
# 2970  2969.0  4332  3.0  There's other lesser enduring brands that kind...
# 2971  2970.0  1294  3.0  And what we've seen in the second half and we'...
# 2972  2971.0  3361  3.0                                        Absolutely.
# 2973  2972.0  3396  4.0  Now I think your point, admittedly a 20 basis ...
# 2974  2973.0  1108  3.0  Progress payments were a usage of gas as expec...
# 2975  2974.0  1659  3.0  Our light duty pickup trucks improved 6.8% at ...
# 2976  2975.0  1744  3.0  And in Q3, I'd say rather that we go through a...
# 2977  2976.0  1278  2.0  So from there we're really wrestling with the ...
# 2978  2977.0  3620  3.0  Obviously Nitro is relatively new across the s...
# 2979  2978.0  2959  3.0  But I wonder if you might comment on if you’ve...
# 2980  2979.0  4382  4.0  And we're very encouraged by what's happening ...
# 2981  2980.0  2952  3.0                                    Good afternoon.
# 2982  2981.0   129  4.0  And I think, what we just wanted to share with...
# 2983  2982.0  2700  4.0  Moving to pro visualization, revenue reached $...
# 2984  2983.0  2255  3.0  Some – there's all sorts of efficiencies that ...
# 2976  Dhivya Suryadevara                answer
# 2977          Larry Culp                answer
# 2978       Dennis Geiger              question
# 2979         Matt Ramsay              question
# 2980        Patrik Frisk                answer
# 2981         Matt Ramsay              question
# 2982        Brian Niccol                answer
# 2983       Colette Kress          presentation
# 2984         Loren Starr                answer
# 2985        Brian Niccol          presentation
# 2986      Jen-Hsun Huang                answer
# 2987        Patrik Frisk                answer
# 2988         John Culver                answer
# 2989        Brian Niccol                answer
# 2990          Larry Culp          presentation
# 2991         Kevin Plank                answer
# 2992  Dhivya Suryadevara                answer
# 2993    John Shrewsberry                answer
# 2994         Pat Grismer          presentation
# 2995         Peter Saleh              question
# 2996      Patrick Davitt              question
# 2997        Mark Hawkins          presentation
# 2998  Dhivya Suryadevara                answer
# 2999      Marty Flanagan                answer
#
# [3000 rows x 8 columns]

# %%
doca = dataset1[3]
doca
# Out:
# 0       Patrik's proven command of this business and t...
# 1       We will be at the Jefferies conference, hardwa...
# 2                                [Operator Instructions].
# 3       Any update that you can share in terms of mile...
# 4       With that, let me turn to the outlook for the ...
# 5                                        Hope that helps.
# 6       Since you're probably wondering and we've talk...
# 7       Good morning and welcome to GE's third quarter...
# 8       There's no other like one time item or whateve...
# 9       We started putting that cash to work, with a $...
# 10      I’m pleased to announce that carne asada is th...
# 11      We have 30.2 million digital active customers ...
# 12      So, I think what you see a little bit relative...
# 13      I think it is very hard to provide guidance on...
# 14                    And I believe that we started that.
# 15       And then on carne asada, if you could help qu...
# 16      So the focus that we've put on the customer ex...
# 17      Mortgage originations increased $5 billion fro...
# 18                            Well, that is Customer 360.
# 19       Our next question comes from the line of Bria...
# 20      From a raw material and tariff perspective to ...
# 21                    We now cover 80% of our store base.
# 22      And don't underestimate the work that we've be...
# 23      Can you put the more detail what you thinking ...
# 24      Additionally, with the lap of the leadership c...
# 25      It's tough getting to $5 billion, I'll tell yo...
# 26      But September was an especially strong month f...
# 27                                     Your line is open.
# 28                            Thanks for all the details.
# 29      So again, source transaction was very importan...
#                               ...
# 2970    There's other lesser enduring brands that kind...
# 2971    And what we've seen in the second half and we'...
# 2972                                          Absolutely.
# 2973    Now I think your point, admittedly a 20 basis ...
# 2974    Progress payments were a usage of gas as expec...
# 2975    Our light duty pickup trucks improved 6.8% at ...
# 2976    And in Q3, I'd say rather that we go through a...
# 2977    So from there we're really wrestling with the ...
# 2978    Obviously Nitro is relatively new across the s...
# 2979    But I wonder if you might comment on if you’ve...
# 2980    And we're very encouraged by what's happening ...
# 2981                                      Good afternoon.
# 2982    And I think, what we just wanted to share with...
# 2983    Moving to pro visualization, revenue reached $...
# 2984    Some – there's all sorts of efficiencies that ...
# 2985    This test tends to be predictive of what happe...
# 2986    And Turing is the world’s first DXR, the first...
# 2987    So, when we think about other brands that are ...
# 2988    We're seeing very good strong growth and uptic...
# 2989    So that's not been a problem to-date and it's ...
# 2990    Aviation is negatively impacted by the MAX gro...
# 2991    Really repositioning our business, restructuri...
# 2992               the segment share within the industry.
# 2993     Yes, so my expectation is that deposit costs ...
# 2994    This is industry-leading domestic growth for a...
# 2995    With 7 million loyalty members now, can you ta...
# 2996                                           Thank you.
# 2997                                Turning to cash flow.
# 2998    That, plus the working capital unwind, constit...
# 2999                          Look, it’s a good question.
# Name: 3, Length: 3000, dtype: object

# %%
lstop_words = ['ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than','okay']

# %%
tfidf = TfidfVectorizer(stop_words=lstop_words)

# %%
response = tfidf.fit_transform(doca)

# %%
tfidf.vocabulary_
# Out:
# {'patrik': 2945,
#  'proven': 3206,
#  'command': 872,
#  'business': 674,
#  'confidence': 951,
#  'armour': 420,
#  'prospects': 3198,
#  'shift': 3714,
#  'defense': 1181,
#  'offense': 2782,
#  'jefferies': 2275,
#  'conference': 950,
#  'hardware': 1971,
#  'communications': 892,
#  'infrastructure': 2171,
#  'summit': 3975,
#  'august': 473,
#  '27': 76,
#  'citi': 815,
#  'global': 1878,
#  'technology': 4052,
#  'september': 3678,
#  '25': 69,
#  'operator': 2824,
#  'instructions': 2203,
#  'update': 4308,
#  'share': 3701,
#  'terms': 4071,
#  'miles': 2610,
#  'driven': 1361,
#  'overall': 2888,
#  'activity': 234,
#  'cruise': 1092,
#  'undergoing': 4262,
#  'second': 3643,
#  'half': 1951,
#  'let': 2394,
#  'turn': 4220,
#  'outlook': 2878,
#  'third': 4092,
#  'quarter': 3251,
#  'fiscal': 1706,
#  '2020': 54,
#  'hope': 2046,
#  'helps': 2012,
#  'since': 3762,
#  're': 3296,
#  'probably': 3142,
#  'wondering': 4468,
#  've': 4350,
#  'talked': 4029,
#  'bit': 589,
#  'cpms': 1068,
#  'last': 2355,
#  'period': 2982,
#  'time': 4114,
#  'product': 3155,
#  'related': 3399,
#  'issues': 2258,
#  'surprise': 3996,
#  'actually': 236,
#  'good': 1890,
#  'morning': 2664,
#  'welcome': 4432,
#  'ge': 1846,
#  '2019': 53,
#  'earnings': 1386,
#  'call': 695,
#  'like': 2420,
#  'one': 2804,
#  'item': 2261,
#  'whatever': 4439,
#  'else': 1439,
#  'profit': 3165,
#  'impact': 2097,
#  'us': 4321,
#  'sounds': 3820,
#  'little': 2443,
#  'understated': 4274,
#  'potentially': 3073,
#  'tax': 4042,
#  'rate': 3281,
#  'started': 3886,
#  'putting': 3240,
#  'cash': 735,
#  'work': 4472,
#  'billion': 587,
#  'industrial': 2156,
#  'debt': 1157,
#  'tender': 4064,
#  'recently': 3325,
#  'announced': 361,
#  'important': 2111,
#  'difficult': 1272,
#  'changes': 775,
#  'pension': 2965,
#  'plan': 3027,
#  'reduce': 3346,
#  'net': 2713,
#  'pleased': 3045,
#  'announce': 360,
#  'carne': 727,
#  'asada': 434,
#  'latest': 2359,
#  'behind': 551,
#  'lifestyle': 2414,
#  'bowls': 622,
#  'rewards': 3535,
#  'program': 3169,
#  'successfully': 3964,
#  'validated': 4336,
#  'process': 3147,
#  'three': 4098,
#  'meeting': 2574,
#  'exceeding': 1564,
#  'expectations': 1603,
#  '30': 83,
#  'million': 2615,
#  'digital': 1277,
#  'active': 231,
#  'customers': 1116,
#  'year': 4503,
#  'ago': 294,
#  'including': 2129,
#  'growth': 1932,
#  'mobile': 2635,
#  'think': 4090,
#  'see': 3655,
#  'relative': 3405,
#  'comp': 895,
#  'strong': 3940,
#  'first': 1705,
#  'date': 1133,
#  'numbers': 2763,
#  'balance': 510,
#  'come': 866,
#  'anticipated': 371,
#  'hard': 1968,
#  'provide': 3207,
#  'guidance': 1939,
#  'measure': 2566,
#  'general': 1852,
#  'believe': 553,
#  'could': 1055,
#  'help': 2008,
#  'quantify': 3250,
#  'cogs': 853,
#  'fourth': 1777,
#  'quarters': 3253,
#  'focus': 1733,
#  'put': 3238,
#  'customer': 1115,
#  'experience': 1610,
#  'stores': 3920,
#  'beverage': 575,
#  'innovation': 2182,
#  'relationships': 3404,
#  'fact': 1638,
#  'executed': 1582,
#  'discipline': 1292,
#  'connection': 964,
#  'scores': 3631,
#  'high': 2018,
#  'mortgage': 2665,
#  'originations': 2860,
#  'increased': 2137,
#  'due': 1371,
#  'higher': 2019,
#  'refi': 3362,
#  'volumes': 4386,
#  'lower': 2474,
#  'interest': 2224,
#  'rates': 3282,
#  'refis': 3369,
#  'increasing': 2139,
#  '40': 101,
#  'well': 4434,
#  '360': 95,
#  'next': 2722,
#  'question': 3256,
#  'comes': 868,
#  'line': 2429,
#  'brian': 643,
#  'nowak': 2759,
#  'morgan': 2663,
#  'stanley': 3882,
#  'raw': 3292,
#  'material': 2541,
#  'tariff': 4038,
#  'perspective': 2995,
#  'point': 3050,
#  'said': 3590,
#  'prior': 3128,
#  'puts': 3239,
#  'takes': 4024,
#  'look': 2458,
#  'number': 2762,
#  'paint': 2909,
#  'brush': 658,
#  'cover': 1064,
#  '80': 158,
#  'store': 3918,
#  'base': 526,
#  'underestimate': 4261,
#  'built': 669,
#  'quality': 3249,
#  'level': 2396,
#  'four': 1776,
#  'plants': 3034,
#  'already': 330,
#  'definitely': 1190,
#  'vehicles': 4352,
#  'station': 3894,
#  'means': 2564,
#  'spend': 3846,
#  'repair': 3439,
#  'detail': 1239,
#  'thinking': 4091,
#  'regionally': 3383,
#  'globally': 1879,
#  'additionally': 243,
#  'lap': 2345,
#  'leadership': 2371,
#  'expect': 1601,
#  'non': 2736,
#  'gaap': 1826,
#  'eps': 1504,
#  'highest': 2020,
#  'q4': 3245,
#  'tough': 4142,
#  'getting': 1866,
#  'll': 2447,
#  'tell': 4059,
#  'industry': 2159,
#  'especially': 1516,
#  'month': 2657,
#  'performance': 2976,
#  'within': 4459,
#  'henley': 2013,
#  'equity': 1510,
#  'side': 3739,
#  'travelling': 4190,
#  'right': 3541,
#  'direction': 1284,
#  'open': 2812,
#  'thanks': 4083,
#  'details': 1241,
#  'source': 3821,
#  'transaction': 4169,
#  'pace': 2903,
#  'picking': 3008,
#  'future': 1822,
#  'know': 2326,
#  'guiding': 1942,
#  'maybe': 2556,
#  'contextualize': 1004,
#  'much': 2680,
#  'improved': 2117,
#  'service': 3686,
#  'showing': 3735,
#  '4q': 122,
#  'start': 3885,
#  'guess': 1935,
#  '1q': 42,
#  'estimate': 1523,
#  'correctly': 1049,
#  'kind': 2317,
#  'soul': 3819,
#  'app': 382,
#  'looking': 2460,
#  'north': 2747,
#  'america': 339,
#  'delivered': 1202,
#  'unfavorably': 4281,
#  'impacted': 2098,
#  'strike': 3939,
#  'united': 4292,
#  'states': 3893,
#  'warranty': 4405,
#  'retail': 3505,
#  'cost': 1052,
#  'previous': 3116,
#  'generation': 1857,
#  'full': 1808,
#  'size': 3774,
#  'pickup': 3009,
#  'trucks': 4206,
#  'suv': 4002,
#  'quite': 3262,
#  'demand': 1209,
#  'equities': 1509,
#  'various': 4347,
#  'flavors': 1717,
#  'lot': 2468,
#  'markets': 2528,
#  'outside': 2885,
#  'seeing': 3657,
#  'etfs': 1530,
#  'traction': 4154,
#  'loren': 2462,
#  'mentioned': 2582,
#  'going': 1886,
#  'hopefully': 2049,
#  'farms': 1653,
#  'solutions': 3804,
#  'win': 4450,
#  'sure': 3993,
#  'sold': 3799,
#  'portion': 3062,
#  'baker': 509,
#  'hughes': 2067,
#  'stake': 3873,
#  'approximately': 406,
#  'proceeds': 3146,
#  'exited': 1595,
#  'wabtec': 4390,
#  'bringing': 647,
#  'another': 367,
#  'goal': 1883,
#  'rebuilding': 3317,
#  'core': 1044,
#  'add': 238,
#  'map': 2518,
#  'stacks': 3866,
#  'address': 244,
#  'exactly': 1559,
#  'sorts': 3817,
#  'increase': 2136,
#  'engineering': 1482,
#  'agility': 293,
#  'way': 4414,
#  'volta': 4384,
#  'surely': 3994,
#  'prime': 3123,
#  'keep': 2306,
#  'continue': 1006,
#  'today': 4123,
#  'touching': 4141,
#  'announcement': 362,
#  'made': 2490,
#  'couple': 1060,
#  'weeks': 4426,
#  'back': 498,
#  'effective': 1411,
#  'january': 2268,
#  'transitioning': 4182,
#  'executive': 1586,
#  'chairman': 767,
#  'brand': 628,
#  'chief': 796,
#  'frisk': 1799,
#  'become': 540,
#  'officer': 2788,
#  'position': 3063,
#  'specifically': 3839,
#  'conversations': 1029,
#  'ongoing': 2807,
#  'really': 3310,
#  'happening': 1964,
#  'technologies': 4051,
#  'challenges': 770,
#  'hear': 1995,
#  'market': 2525,
#  'excited': 1572,
#  'new': 2718,
#  'span': 3827,
#  'entire': 1498,
#  'portfolio': 3060,
#  'adjusting': 251,
#  'would': 4489,
#  '24': 66,
#  'quarterly': 3252,
#  'record': 3338,
#  'please': 3044,
#  'go': 1882,
#  'ahead': 299,
#  'rocky': 3554,
#  'gupta': 1944,
#  'treasurer': 4191,
#  'vice': 4362,
#  'president': 3107,
#  'investor': 2247,
#  'relations': 3402,
#  'sg': 3699,
#  'expense': 1607,
#  '551': 133,
#  'better': 573,
#  'expected': 1604,
#  'continued': 1007,
#  'management': 2507,
#  'efforts': 1418,
#  'unrealized': 4303,
#  'marketing': 2526,
#  'utilized': 4333,
#  'coupled': 1061,
#  'planned': 3029,
#  'depreciation': 1231,
#  'timing': 4118,
#  'openings': 2815,
#  'capital': 712,
#  'expenditures': 1606,
#  'fundamentally': 1815,
#  'offset': 2791,
#  'legacy': 2387,
#  'referenced': 3358,
#  'prepared': 3097,
#  'remarks': 3421,
#  'consolidation': 983,
#  'alstom': 332,
#  'jvs': 2301,
#  'heavy': 2003,
#  'duty': 1376,
#  'launches': 2363,
#  'sorry': 3815,
#  'redundant': 3352,
#  'previously': 3117,
#  'indicated': 2149,
#  'wanted': 4400,
#  'clarify': 819,
#  'certainly': 761,
#  'area': 413,
#  'making': 2505,
#  'progress': 3174,
#  'ashish': 435,
#  'kohli': 2329,
#  'head': 1982,
#  'ir': 2251,
#  'gives': 1872,
#  'far': 1650,
#  'ceiling': 750,
#  'footwear': 1750,
#  'kevin': 2313,
#  'alluded': 326,
#  'earlier': 1381,
#  'belief': 552,
#  'pipeline': 3016,
#  'forward': 1769,
#  'yes': 4505,
#  'recovery': 3343,
#  'anticipate': 370,
#  'small': 3792,
#  'losses': 2466,
#  'sustained': 4001,
#  'recovered': 3342,
#  'capacity': 710,
#  'constraints': 990,
#  'say': 3611,
#  'real': 3305,
#  'even': 1536,
#  'fight': 1679,
#  'things': 4089,
#  'sort': 3816,
#  'helping': 2011,
#  'fee': 1669,
#  'positive': 3067,
#  'versus': 4358,
#  'may': 2555,
#  'flip': 1722,
#  'q2': 3243,
#  '11': 11,
#  '66': 143,
#  'john': 2284,
#  'china': 799,
#  'loyalty': 2478,
#  'members': 2578,
#  'early': 1382,
#  'working': 4478,
#  'remediation': 3423,
#  'also': 331,
#  'giving': 1873,
#  'yet': 4507,
#  'thank': 4081,
#  'name': 2691,
#  'christina': 812,
#  'discussed': 1308,
#  'delivery': 1206,
#  'transactions': 4171,
#  'margin': 2522,
#  'dilutive': 1282,
#  'total': 4138,
#  'theories': 4084,
#  'years': 4504,
#  'decelerate': 1160,
#  'perhaps': 2981,
#  'hitting': 2035,
#  'max': 2552,
#  'premium': 3092,
#  'given': 1871,
#  'supply': 3987,
#  'run': 3578,
#  'late': 2357,
#  'november': 2758,
#  'plans': 3031,
#  'driving': 1365,
#  'usage': 4322,
#  'guests': 1938,
#  'came': 699,
#  'bugs': 664,
#  'causing': 744,
#  'deceleration': 1161,
#  'places': 3025,
#  'japan': 2269,
#  'users': 4327,
#  'coming': 871,
#  'country': 1059,
#  'ph': 2999,
#  'offer': 2783,
#  'monetization': 2652,
#  'potential': 3072,
#  'obviously': 2775,
#  'response': 3492,
#  'article': 429,
#  'appeared': 387,
#  'gone': 1889,
#  'looked': 2459,
#  'account': 202,
#  'closure': 844,
#  'information': 2169,
#  'great': 1912,
#  'deal': 1146,
#  'meet': 2573,
#  'regulators': 3389,
#  'uses': 4328,
#  'says': 3612,
#  'talk': 4028,
#  'renewables': 3434,
#  'bulk': 670,
#  'revenue': 3520,
#  'onshore': 2810,
#  'wind': 4451,
#  '50': 123,
#  'uc': 4246,
#  'berkeley': 564,
#  'br': 624,
#  'team': 4045,
#  'take': 4021,
#  'incredibly': 2142,
#  'progressive': 3178,
#  'stance': 3876,
#  'grateful': 1910,
#  'course': 1063,
#  'salesforce': 3597,
#  'greatest': 1914,
#  'platform': 3036,
#  'change': 773,
#  'ai': 300,
#  'network': 2715,
#  'stick': 3910,
#  'roughly': 3567,
#  'midsole': 2604,
#  'brexit': 642,
#  'environment': 1501,
#  'tremendous': 4195,
#  'headwind': 1989,
#  'degree': 1194,
#  'investment': 2245,
#  'teams': 4048,
#  'aviation': 490,
#  'franchise': 1782,
#  'installed': 2194,
#  'nearly': 2702,
#  '70': 146,
#  '000': 0,
#  'engines': 1483,
#  'beyond': 577,
#  'completed': 916,
#  'pre': 3078,
#  'funding': 1818,
#  'estimated': 1524,
#  'minimum': 2622,
#  'erisa': 1515,
#  'requirements': 3469,
#  '2021': 55,
#  '2022': 56,
#  'commercial': 879,
#  'loans': 2450,
#  'stable': 3864,
#  'linked': 2434,
#  'leased': 2380,
#  'financing': 1695,
#  'largely': 2351,
#  'declines': 1172,
#  'estate': 1521,
#  'guys': 1946,
#  'however': 2061,
#  'many': 2517,
#  'areas': 414,
#  'loss': 2465,
#  'profits': 3168,
#  'stoppage': 3915,
#  'significant': 3745,
#  'happen': 1962,
#  'sometime': 3809,
#  'later': 2358,
#  'reluctant': 3414,
#  'give': 1870,
#  'chipotlane': 801,
#  'returns': 3517,
#  'around': 421,
#  'key': 2314,
#  'levers': 2403,
#  'improvement': 2118,
#  'corner': 1046,
#  'speakers': 3833,
#  'answer': 368,
#  'session': 3689,
#  'priorities': 3129,
#  'benefit': 559,
#  'operating': 2819,
#  'embedded': 1443,
#  'ask': 438,
#  'andrew': 355,
#  'tried': 4200,
#  'less': 2392,
#  'big': 582,
#  'segments': 3665,
#  'low': 2473,
#  'single': 3763,
#  'digit': 1276,
#  'deposits': 1230,
#  'reasonable': 3312,
#  'proxy': 3211,
#  'placeholder': 3024,
#  'unfolds': 4283,
#  'range': 3275,
#  'different': 1267,
#  'outcomes': 2869,
#  'consistent': 978,
#  'might': 2606,
#  'forecast': 1753,
#  'paths': 2940,
#  'mid': 2602,
#  'digits': 1278,
#  'percentage': 2971,
#  'income': 2131,
#  'mark': 2524,
#  'comments': 877,
#  'tableau': 4015,
#  'along': 329,
#  'continuing': 1009,
#  'improve': 2116,
#  'relevance': 3410,
#  'formats': 1763,
#  'moving': 2675,
#  'funnel': 1820,
#  'types': 4239,
#  'advertising': 270,
#  'available': 486,
#  'ought': 2865,
#  'auction': 470,
#  'dynamics': 1380,
#  'providing': 3210,
#  'frictionless': 1798,
#  'access': 195,
#  'enhancing': 1485,
#  'awareness': 495,
#  'emphasizing': 1452,
#  'deliciousness': 1197,
#  'operations': 2823,
#  'delighting': 1200,
#  'hospitality': 2053,
#  'throughput': 4103,
#  'chain': 766,
#  'ensuring': 1490,
#  'ingredients': 2172,
#  'food': 1744,
#  'integrity': 2210,
#  'standards': 3879,
#  'super': 3976,
#  'install': 2193,
#  'pascal': 2932,
#  'notebook': 2751,
#  'helpful': 2010,
#  'hi': 2015,
#  'erinn': 1514,
#  'joe': 2283,
#  'partially': 2920,
#  'need': 2707,
#  'figure': 1680,
#  'trucking': 4205,
#  'continues': 1008,
#  'major': 2500,
#  'driver': 1362,
#  'opportunity': 2832,
#  'firm': 1702,
#  'evolution': 1552,
#  'two': 4235,
#  'effect': 1410,
#  'began': 544,
#  'responding': 3490,
#  'july': 2294,
#  '2017': 51,
#  'request': 3464,
#  'documents': 1327,
#  'folks': 1739,
#  'power': 3074,
#  'orders': 2850,
#  '54': 130,
#  'reported': 3449,
#  '34': 90,
#  'organically': 2854,
#  'steam': 3903,
#  'system': 4011,
#  '49': 119,
#  'repeat': 3442,
#  'large': 2350,
#  'nuclear': 2761,
#  'equipment': 1507,
#  'contract': 1011,
#  'constant': 984,
#  'contact': 997,
#  'throughout': 4102,
#  'ready': 3302,
#  'prompt': 3188,
#  'safe': 3588,
#  'restart': 3494,
#  'ratified': 3284,
#  'drivers': 1363,
#  'largest': 2353,
#  'reasons': 3313,
#  'gross': 1923,
#  'event': 1538,
#  'want': 4399,
#  'briefly': 645,
#  'labor': 2336,
#  'agreement': 297,
#  '501': 125,
#  'investments': 2246,
#  'varies': 4345,
#  'geography': 1862,
#  'remainder': 3416,
#  'reduction': 3350,
#  'allowance': 321,
#  'predominantly': 3085,
#  'collateral': 857,
#  'value': 4340,
#  'residential': 3478,
#  'written': 4494,
#  'significantly': 3746,
#  'current': 1109,
#  'credit': 1081,
#  'cycle': 1120,
#  'larger': 2352,
#  'amount': 346,
#  'door': 1335,
#  'partner': 2928,
#  'doors': 1336,
#  'fundamental': 1814,
#  'strengths': 3936,
#  'organization': 2855,
#  'hey': 2014,
#  'taking': 4025,
#  'lapping': 2346,
#  'sales': 3596,
#  'impressive': 2115,
#  'equally': 1505,
#  'average': 489,
#  'ticket': 4107,
#  'turning': 4223,
#  'margins': 2523,
#  'fy': 1825,
#  'basis': 531,
#  'points': 3052,
#  'appreciate': 399,
#  'path': 2939,
#  'function': 1811,
#  'control': 1022,
#  'without': 4460,
#  '1st': 43,
#  'front': 1800,
#  'feet': 1673,
#  'enacted': 1462,
#  'policies': 3054,
#  'list': 2438,
#  '4a': 120,
#  '4b': 121,
#  'considered': 975,
#  'feel': 1671,
#  'spot': 3854,
#  'switch': 4005,
#  'near': 2701,
#  'term': 4069,
#  'focused': 1734,
#  'deliver': 1201,
#  'options': 2845,
#  'long': 2456,
#  'people': 2967,
#  'till': 4113,
#  'end': 1469,
#  'find': 1697,
#  'calls': 698,
#  'towards': 4147,
#  'stepping': 3906,
#  'mix': 2632,
#  'price': 3118,
#  'channel': 777,
#  'something': 3808,
#  'step': 3904,
#  'though': 4093,
#  'pull': 3220,
#  'still': 3912,
#  'achieve': 216,
#  'begin': 545,
#  'certifications': 762,
#  'examples': 1561,
#  'life': 2413,
#  'ease': 1387,
#  'use': 4323,
#  'compound': 926,
#  'sustainable': 4000,
#  'flows': 1728,
#  'complete': 915,
#  'phases': 3001,
#  'integration': 2209,
#  'belinda': 554,
#  'leo': 2391,
#  'ways': 4415,
#  'anchored': 354,
#  'flywheel': 1731,
#  'done': 1334,
#  'forwards': 1771,
#  'picture': 3011,
#  'brands': 630,
#  'endure': 1473,
#  'card': 721,
#  'purchase': 3226,
#  'volume': 4385,
#  'debit': 1155,
#  'taught': 4041,
#  'slower': 3788,
#  'economy': 1400,
#  'omar': 2802,
#  'saad': 3585,
#  'evercore': 1542,
#  'isi': 2254,
#  'summary': 3973,
#  'reducing': 3349,
#  'risk': 3544,
#  'across': 226,
#  'reflecting': 3372,
#  'results': 3503,
#  'trends': 4198,
#  'highlighted': 2022,
#  'hold': 2036,
#  'disconnect': 1299,
#  'quickly': 3260,
#  'touch': 4140,
#  'anything': 375,
#  'incremental': 2143,
#  'leverage': 2400,
#  'slide': 3783,
#  '14': 25,
#  'uk': 4247,
#  'five': 1708,
#  'dreamforce': 1358,
#  'factoring': 1641,
#  'updated': 4309,
#  'diluted': 1280,
#  'adjusted': 250,
#  'discussions': 1311,
#  'union': 4288,
#  'necessary': 2704,
#  'underlying': 4264,
#  '26': 74,
#  '29': 80,
#  'vary': 4348,
#  'based': 527,
#  'discrete': 1305,
#  'items': 2262,
#  'stock': 3913,
#  'option': 2842,
#  'exercises': 1588,
#  '139': 24,
#  'rtx': 3576,
#  'studio': 3950,
#  'models': 2640,
#  'oems': 2781,
#  'geographies': 1861,
#  'pronounced': 3189,
#  'financial': 1692,
#  'allen': 315,
#  'summarized': 3971,
#  'highlight': 2021,
#  'momentum': 2650,
#  'opportunities': 2831,
#  'best': 568,
#  'events': 1539,
#  'adding': 240,
#  'got': 1894,
#  'remain': 3415,
#  'confident': 952,
#  'strength': 3932,
#  'twitter': 4233,
#  'company': 897,
#  'tower': 4148,
#  'wells': 4435,
#  'fargo': 1651,
#  'larry': 2354,
#  'following': 1742,
#  'comment': 874,
#  'uncertain': 4254,
#  'macro': 2489,
#  'crisp': 1083,
#  'appears': 388,
#  'everywhere': 1549,
#  'seen': 3661,
#  'ordering': 2849,
#  'get': 1864,
#  'car': 720,
#  'nice': 2724,
#  'unlock': 4296,
#  'chipotle': 803,
#  'additional': 242,
#  'complexity': 921,
#  'running': 3579,
#  'traditional': 4159,
#  'drive': 1360,
#  'sharon': 3707,
#  'ballpark': 515,
#  'jensen': 2279,
#  'colette': 856,
#  'street': 3931,
#  'endless': 1471,
#  'strategy': 3929,
#  'reviews': 3528,
#  'jamie': 2267,
#  'questions': 3257,
#  'menu': 2583,
#  'relation': 3401,
#  'execute': 1581,
#  'turnaround': 4221,
#  'international': 2230,
#  'decisive': 1166,
#  'steps': 3907,
#  'profitability': 3166,
#  'every': 1544,
#  'participate': 2922,
#  'cease': 747,
#  'past': 2937,
#  'added': 239,
#  'einstein': 1421,
#  'case': 733,
#  'routing': 3572,
#  'route': 3570,
#  'support': 3988,
#  'cases': 734,
#  'skill': 3777,
#  'florence': 1725,
#  'facility': 1637,
#  'reliance': 3412,
#  'short': 3727,
#  'flat': 1712,
#  '2018': 52,
#  'reminder': 3426,
#  'presentation': 3101,
#  'include': 2126,
#  'statements': 3892,
#  'reflect': 3370,
#  'expectation': 1602,
#  'rpo': 3574,
#  '12': 15,
#  '23': 63,
#  'currency': 1108,
#  'intend': 2214,
#  'transparency': 4185,
#  'broadly': 654,
#  'role': 3557,
#  'political': 3056,
#  'consumer': 994,
#  'portfolios': 3061,
#  'justin': 2300,
#  'archive': 412,
#  'webcast': 4422,
#  'website': 4423,
#  'thursday': 4105,
#  '28': 78,
#  'dan': 1128,
#  'levy': 2404,
#  'suisse': 3968,
#  'emea': 1445,
#  'loan': 2449,
#  '19': 39,
#  'held': 2006,
#  'result': 3500,
#  'exercising': 1589,
#  'cleanup': 826,
#  'terminate': 4070,
#  '20': 44,
#  '2008': 47,
#  'securitizations': 3652,
#  'leave': 2383,
#  'unique': 4289,
#  'recent': 3324,
#  'impacting': 2100,
#  'flow': 1726,
#  'primarily': 3121,
#  'relates': 3400,
#  'americas': 341,
#  'segment': 3662,
#  'yeah': 4502,
#  ...}

# %%
print(response[0])
# Out:
#   (0, 2945)	0.2874155081291462
#   (0, 3206)	0.37524780478244346
#   (0, 872)	0.37524780478244346
#   (0, 674)	0.1828437702590124
#   (0, 951)	0.2843013857436154
#   (0, 420)	0.2736315358070561
#   (0, 3198)	0.34396130945433506
#   (0, 3714)	0.2874155081291462
#   (0, 1181)	0.35694637823651243
#   (0, 2782)	0.34396130945433506

# %%
response_array = response.toarray()

# %%
response_array.shape
# Out:
# (3000, 4519)

# %%
kmeans = KMeans(n_clusters=500).fit(response)

# %%
kmeans = KMeans(n_clusters=8).fit(response_array)

# %%
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.inertia_
# Out:
# 2748.094477185481

# %%
lines_for_predicting = ["Mike is awesome!", "some androids is there in the brain"]
kmeans.predict(tfidf.transform(lines_for_predicting))
# Out:
# array([0, 0])

# %%
kmeans.inertia_
# Out:
# 2765.717065840311

# %%
SSE = []
for cluster in range(1,20):
    kmeans = KMeans(n_jobs = -1, n_clusters = cluster, init='k-means++')
    kmeans.fit(response)
    SSE.append(kmeans.inertia_)

# %%
# converting the results into a dataframe and plotting them
frame = pd.DataFrame({'Cluster':range(1,20), 'SSE':SSE})
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
kmeans = KMeans(n_jobs = -1, n_clusters = 8, init='k-means++')
kmeans.fit(response)
pred = kmeans.predict(response)

# %%
pred
#https://www.analyticsvidhya.com/blog/2019/08/comprehensive-guide-k-means-clustering/
# Out:
# array([0, 0, 0, ..., 0, 0, 6])

# %%
frame = pd.DataFrame(response)
frame['cluster'] = pred
frame['cluster'].value_counts()
# Out:
# 0    1726
# 3     490
# 1     430
# 6      99
# 2      97
# 4      87
# 5      48
# 7      23
# Name: cluster, dtype: int64

# %%
frame.head()
# Out:
#                                                    0  cluster
# 0    (0, 2946)\t0.2874155081291462\n  (0, 3207)\t...        0
# 1    (0, 2275)\t0.28306688712381356\n  (0, 950)\t...        0
# 2    (0, 2825)\t0.6822373995473022\n  (0, 2203)\t...        0
# 3    (0, 4309)\t0.29788868443226524\n  (0, 3702)\...        0
# 4    (0, 2394)\t0.41422165504694397\n  (0, 4221)\...        1

# %%
response
# Out:
# <3000x4520 sparse matrix of type '<class 'numpy.float64'>'
# 	with 28350 stored elements in Compressed Sparse Row format>

# %%
dataset1['cluster'] = pred
dataset1['cluster'].value_counts()
# Out:
# 0    1726
# 3     490
# 1     430
# 6      99
# 2      97
# 4      87
# 5      48
# 7      23
# Name: cluster, dtype: int64

# %%
dataset1.head(10)
# Out:
#      0     1    2                                                  3     4  \
# 0  NaN  4065  4.0  Patrik's proven command of this business and t...   UAA
# 1  0.0  2730  3.0  We will be at the Jefferies conference, hardwa...  NVDA
# 2  1.0  4044  3.0                           [Operator Instructions].   UAA
# 3  2.0  1833  3.0  Any update that you can share in terms of mile...    GM
# 4  3.0  2721  3.0  With that, let me turn to the outlook for the ...  NVDA
# 5  4.0  3984  3.0                                   Hope that helps.  TWTR
# 6  5.0  3929  1.0  Since you're probably wondering and we've talk...  TWTR
# 7  6.0  1004  3.0  Good morning and welcome to GE's third quarter...    GE
# 8  7.0  2010  2.0  There's no other like one time item or whateve...    GM
# 9  8.0  1042  4.0  We started putting that cash to work, with a $...    GE
#
#                                                    5                   6  \
# 0  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...         Kevin Plank
# 1  NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...       Colette Kress
# 2  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...            Operator
# 3  General Motors Company (NYSE:GM) Q3 2019 Earni...       Itay Michaeli
# 4  NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...       Colette Kress
# 5  Twitter, Inc. (NYSE:TWTR) Q3 2019 Results Earn...           Ned Segal
# 6  Twitter, Inc. (NYSE:TWTR) Q3 2019 Results Earn...           Ned Segal
# 7  General Electric Company (NYSE:GE) Q3 2019 Ear...       Steve Winoker
# 8  General Motors Company (NYSE:GM) Q3 2019 Earni...  Dhivya Suryadevara
# 9  General Electric Company (NYSE:GE) Q3 2019 Ear...          Larry Culp
#
#                       7  cluster
# 0          presentation        0
# 1          presentation        0
# 2  operator_instruction        0
# 3              question        0
# 4          presentation        1
# 5                answer        0
# 6                answer        3
# 7          presentation        1
# 8                answer        0
# 9          presentation        1

# %%
dataset1.cluster.mean()
# Out:
# 1.1456666666666666

# %%
dataset1[7].value_counts()
# Out:
# answer                  1321
# presentation             889
# question                 591
# operator_instruction     199
# Name: 7, dtype: int64

# %%
dataset1.groupby(7).count()[['cluster']]
# Out:
#                       cluster
# 7
# answer                   1321
# operator_instruction      199
# presentation              889
# question                  591

# %%
dataset1.groupby('cluster').count()[[7]]
# Out:
#             7
# cluster
# 0        1726
# 1         430
# 2          97
# 3         490
# 4          87
# 5          48
# 6          99
# 7          23

# %%
cool = dataset1.groupby([7,'cluster'])['cluster'].count()
cool
# Out:
# 7                     cluster
# answer                0          757
#                       1           98
#                       2           10
#                       3          381
#                       4           16
#                       5           41
#                       6           14
#                       7            4
# operator_instruction  0           93
#                       1            6
#                       2           31
#                       6           69
# presentation          0          544
#                       1          275
#                       2            8
#                       3           41
#                       4           15
#                       5            1
#                       6            4
#                       7            1
# question              0          332
#                       1           51
#                       2           48
#                       3           68
#                       4           56
#                       5            6
#                       6           12
#                       7           18
# Name: cluster, dtype: int64

# %%
cool.plot.bar()

# %%
coolticker = dataset1.groupby([4,'cluster'])['cluster'].count()
coolticker
# Out:
# 4     cluster
# CMG   0          166
#       1           24
#       2           18
#       3           61
#       4            8
#       5           13
#       6           14
#       7            2
# CRM   0          165
#       1           45
#       2           11
#       3           42
#       4           12
#       5            7
#       6            7
#       7            1
# GE    0          191
#       1           83
#       2            4
#       3           53
#       4            5
#       5            3
#       6            2
# GM    0          164
#       1           52
#       2            2
#       3           51
#       4            6
#       5            3
#       6            7
#                 ...
# SBUX  0          196
#       1           62
#       2            7
#       3           44
#       4            5
#       5            2
#       6           14
#       7            1
# TWTR  0          149
#       1           12
#       2           13
#       3           21
#       4           16
#       6           13
#       7            3
# UAA   0          211
#       1           37
#       2           21
#       3           83
#       4           15
#       6           12
#       7            3
# WFC   0          139
#       1           64
#       2            4
#       3           33
#       4            4
#       5            6
#       6            8
#       7            8
# Name: cluster, Length: 75, dtype: int64

# %%
coolticker.plot.bar()

# %%
result = dataset1.sort_values('cluster', ascending=[1])

# %%
result
# Out:
#            0     1    2                                                  3  \
# 0        NaN  4065  4.0  Patrik's proven command of this business and t...
# 1771  1770.0  4150  4.0  To give a little more color here, along with o...
# 1769  1768.0  2024  3.0  If we get this working capital benefit in 2020...
# 1768  1767.0  1459  2.0  The second piece, the transactional book, we a...
# 1767  1766.0  1608  4.0  With the XT6 joining the lineup, we expect Cad...
# 1764  1763.0  4659  2.0  We just need to start running the play and run...
# 1762  1761.0  2804  3.0  And that’s one of the reasons why our Tesla fo...
# 1761  1760.0   598  4.0         Well, Saleforce skills are in high demand.
# 1759  1758.0  1928  4.0  And more specifically, you've obviously been p...
# 1758  1757.0  3032  3.0  They need powerful computers to do rendering a...
# 1756  1755.0   332  3.0  I am wanted to follow up on the Chipotlanes an...
# 1754  1753.0  1221  3.0  We continue to push control and accountability...
# 1753  1752.0  5003  3.0  And so, that may take months or even quarters ...
# 1752  1751.0  4261  2.0  And then, Dave, I wanted to just follow-up on ...
# 1750  1749.0  2389  3.0                                 Your line is open.
# 1772  1771.0  2938  3.0  And that’s one of the reasons why you hear peo...
# 1749  1748.0  2779  3.0  If I could follow-up on the data center side, ...
# 1746  1745.0  3417  3.0  So even while diluting our margin percentage, ...
# 1744  1743.0  4371  3.0                                    I'll start off.
# 1742  1741.0  3469  4.0  We now have crossed the 10 million Starbucks R...
# 1741  1740.0  1253  3.0  This positions us well especially against the ...
# 1738  1737.0  2644  3.0   With that, let me turn the call over to Colette.
# 1737  1736.0    26  4.0  Let me give you an update on each of these sta...
# 1735  1734.0  3521  4.0  Number one, it's overlapping some unusual bene...
# 1734  1733.0  3440  3.0                    We launched Starbucks Delivers.
# 1733  1732.0   177  3.0    Are there cost savings that are coming through?
# 1732  1731.0    65  3.0  I believe we are still in the early stages of ...
# 1731  1730.0   755  3.0   Well, thanks Heather and I'll let Mark direct...
# 1730  1729.0  1334  3.0   Hey, would love to get an update on the Power...
# 1728  1727.0  1458  4.0  And that all brings it down to how do we conti...
# ...      ...   ...  ...                                                ...
# 2781  2780.0  1813  3.0   Your next question comes from the line of Ita...
# 1018  1017.0  4031  3.0         So I think that will be our last question.
# 2879  2878.0  3340  3.0                 Please proceed with your question.
# 369    368.0  4398  3.0  I guess just first, kind of a housekeeping que...
# 1203  1202.0  4246  3.0  Our next question comes from Jonathan Komp wit...
# 1787  1786.0  3807  3.0   Your next question comes from the line of Hea...
# 1999  1998.0  3891  3.0  The question comes from the account of @Bitcoi...
# 1526  1525.0  3939  3.0                                              Okay.
# 2566  2565.0  4033  3.0                                              Okay.
# 845    844.0  4914  3.0                         Okay, all right, terrific.
# 2135  2134.0   291  3.0                                              Okay.
# 2915  2914.0  3597  3.0                                       Okay, great.
# 743    742.0  4491  3.0                                       Okay, great.
# 45      44.0  2213  3.0                                      Okay, thanks.
# 311    310.0   847  3.0                                              Okay.
# 2480  2479.0  2577  3.0                                              Okay.
# 2295  2294.0  2416  3.0                                              Okay.
# 2838  2837.0  3746  3.0                                              Okay.
# 1239  1238.0  2457  3.0                                              Okay.
# 778    777.0  4260  3.0                                       Okay, great.
# 2028  2027.0  4938  3.0                                      Okay, thanks.
# 2802  2801.0  5080  3.0   Okay, that's helpful, and then one last quest...
# 2713  2712.0  2401  3.0                                       Okay, great.
# 1581  1580.0  4932  3.0   Okay, and guys, one more follow-up on the exp...
# 1620  1619.0   302  3.0                                              Okay.
# 1613  1612.0  5005  3.0                                              Okay.
# 1313  1312.0  4903  3.0                          Okay, perfect, thank you.
# 132    131.0  4999  3.0                                              Okay.
# 2486  2485.0  4271  3.0                                  Okay, understood.
# 2549  2548.0  5154  3.0                                      Okay, thanks.
#
#          4                                                  5  \
# 0      UAA  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...
# 1771   UAA  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...
# 1769    GM  General Motors Company (NYSE:GM) Q3 2019 Earni...
# 1768    GE  General Electric Company (NYSE:GE) Q3 2019 Ear...
# 1767    GM  General Motors Company (NYSE:GM) Q3 2019 Earni...
# 1764   UAA  Under Armour, Inc. (NYSE:UAA) Q3 2019 Results 