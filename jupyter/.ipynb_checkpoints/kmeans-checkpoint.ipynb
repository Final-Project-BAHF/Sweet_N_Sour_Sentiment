# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import pandas as pd

# %%
df = pd.read_excel("sentence_sample_mh.xlsx")
df.to_csv("data.csv", sep="|")
dataset1 = pd.read_csv('data.csv', header=None, sep='|')
dataset1
# Out:
#            0     1          2  \
# 0        NaN    id  Sentiment
# 1        0.0  4065        4.0
# 2        1.0  2730        3.0
# 3        2.0  4044        3.0
# 4        3.0  1833        3.0
# 5        4.0  2721        3.0
# 6        5.0  3984        3.0
# 7        6.0  3929        1.0
# 8        7.0  1004        3.0
# 9        8.0  2010        2.0
# 10       9.0  1042        4.0
# 11      10.0    28        5.0
# 12      11.0  4837        4.0
# 13      12.0  1563        4.0
# 14      13.0  2226        2.0
# 15      14.0  4590        3.0
# 16      15.0   348        3.0
# 17      16.0  3609        5.0
# 18      17.0  4820        4.0
# 19      18.0   574        3.0
# 20      19.0  4004        3.0
# 21      20.0  1995        2.0
# 22      21.0  3479        4.0
# 23      22.0  1937        2.0
# 24      23.0  1823        3.0
# 25      24.0  3266        5.0
# 26      25.0  4671        1.0
# 27      26.0  2480        4.0
# 28      27.0  2581        3.0
# 29      28.0  2293        3.0
# ...      ...   ...        ...
# 2971  2970.0  4332        3.0
# 2972  2971.0  1294        3.0
# 2973  2972.0  3361        3.0
# 2974  2973.0  3396        4.0
# 2975  2974.0  1108        3.0
# 2976  2975.0  1659        3.0
# 2977  2976.0  1744        3.0
# 2978  2977.0  1278        2.0
# 2979  2978.0  3620        3.0
# 2980  2979.0  2959        3.0
# 2981  2980.0  4382        4.0
# 2982  2981.0  2952        3.0
# 2983  2982.0   129        4.0
# 2984  2983.0  2700        4.0
# 2985  2984.0  2255        3.0
# 2986  2985.0    27        4.0
# 2987  2986.0  3021        3.0
# 2988  2987.0  4347        3.0
# 2989  2988.0  3532        4.0
# 2990  2989.0   452        3.0
# 2991  2990.0  1234        3.0
# 2992  2991.0  4650        3.0
# 2993  2992.0  1719        3.0
# 2994  2993.0  4922        3.0
# 2995  2994.0  3220        4.0
# 2996  2995.0   459        3.0
# 2997  2996.0  2391        3.0
# 2998  2997.0   680        3.0
# 2999  2998.0  2009        3.0
# 3000  2999.0  2466        3.0
#
#                                                       3       4  \
# 0                                              sentence  ticker
# 1     Patrik's proven command of this business and t...     UAA
# 2     We will be at the Jefferies conference, hardwa...    NVDA
# 3                              [Operator Instructions].     UAA
# 4     Any update that you can share in terms of mile...      GM
# 5     With that, let me turn to the outlook for the ...    NVDA
# 6                                      Hope that helps.    TWTR
# 7     Since you're probably wondering and we've talk...    TWTR
# 8     Good morning and welcome to GE's third quarter...      GE
# 9     There's no other like one time item or whateve...      GM
# 10    We started putting that cash to work, with a $...      GE
# 11    I’m pleased to announce that carne asada is th...     CMG
# 12    We have 30.2 million digital active customers ...     WFC
# 13    So, I think what you see a little bit relative...      GE
# 14    I think it is very hard to provide guidance on...     IVZ
# 15                  And I believe that we started that.     UAA
# 16     And then on carne asada, if you could help qu...     CMG
# 17    So the focus that we've put on the customer ex...    SBUX
# 18    Mortgage originations increased $5 billion fro...     WFC
# 19                          Well, that is Customer 360.     CRM
# 20     Our next question comes from the line of Bria...    TWTR
# 21    From a raw material and tariff perspective to ...      GM
# 22                  We now cover 80% of our store base.    SBUX
# 23    And don't underestimate the work that we've be...      GM
# 24    Can you put the more detail what you thinking ...      GM
# 25    Additionally, with the lap of the leadership c...    SBUX
# 26    It's tough getting to $5 billion, I'll tell yo...     UAA
# 27    But September was an especially strong month f...     IVZ
# 28                                   Your line is open.     IVZ
# 29                          Thanks for all the details.     IVZ
# ...                                                 ...     ...
# 2971  There's other lesser enduring brands that kind...     UAA
# 2972  And what we've seen in the second half and we'...      GE
# 2973                                        Absolutely.    SBUX
# 2974  Now I think your point, admittedly a 20 basis ...    SBUX
# 2975  Progress payments were a usage of gas as expec...      GE
# 2976  Our light duty pickup trucks improved 6.8% at ...      GM
# 2977  And in Q3, I'd say rather that we go through a...      GM
# 2978  So from there we're really wrestling with the ...      GE
# 2979  Obviously Nitro is relatively new across the s...    SBUX
# 2980  But I wonder if you might comment on if you’ve...    NVDA
# 2981  And we're very encouraged by what's happening ...     UAA
# 2982                                    Good afternoon.    NVDA
# 2983  And I think, what we just wanted to share with...     CMG
# 2984  Moving to pro visualization, revenue reached $...    NVDA
# 2985  Some – there's all sorts of efficiencies that ...     IVZ
# 2986  This test tends to be predictive of what happe...     CMG
# 2987  And Turing is the world’s first DXR, the first...    NVDA
# 2988  So, when we think about other brands that are ...     UAA
# 2989  We're seeing very good strong growth and uptic...    SBUX
# 2990  So that's not been a problem to-date and it's ...     CMG
# 2991  Aviation is negatively impacted by the MAX gro...      GE
# 2992  Really repositioning our business, restructuri...     UAA
# 2993             the segment share within the industry.      GM
# 2994   Yes, so my expectation is that deposit costs ...     WFC
# 2995  This is industry-leading domestic growth for a...    SBUX
# 2996  With 7 million loyalty members now, can you ta...     CMG
# 2997                                         Thank you.     IVZ
# 2998                              Turning to cash flow.     CRM
# 2999  That, plus the working capital unwind, constit...      GM
# 3000                        Look, it’s a good question.     IVZ
#
#                                                       5                   6  \
# 0                                            call_title             speaker
# 1     Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...         Kevin Plank
# 2     NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...       Colette Kress
# 3     Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...            Operator
# 4     General Motors Company (NYSE:GM) Q3 2019 Earni...       Itay Michaeli
# 5     NVIDIA Corporation (NASDAQ:NVDA) Q2 2020 Earni...       Colette Kress
# 6     Twitter, Inc. (NYSE:TWTR) Q3 2019 Results Earn...           Ned Segal
# 7     Twitter, Inc. (NYSE:TWTR) Q3 2019 Results Earn...           Ned Segal
# 8     General Electric Company (NYSE:GE) Q3 2019 Ear...       Steve Winoker
# 9     General Motors Company (NYSE:GM) Q3 2019 Earni...  Dhivya Suryadevara
# 10    General Electric Company (NYSE:GE) Q3 2019 Ear...          Larry Culp
# 11    Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...        Brian Niccol
# 12    Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...    John Shrewsberry
# 13    General Electric Company (NYSE:GE) Q3 2019 Ear...          Larry Culp
# 14    Invesco Ltd. (NYSE:IVZ) Q3 2019 Earnings Confe...         Loren Starr
# 15    Under Armour, Inc. (NYSE:UAA) Q3 2019 Results ...         Kevin Plank
# 16    Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...      Sharon Zackfia
# 17    Starbucks Corporation (NASDAQ:SBUX) Q4 2019 Ea...       Kevin Johnson
# 18    Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...    John Shrewsberry
# 19    Salesforce.com, inc. (NYSE:CRM) Q2 2020 Result...        Marc Benioff
# 20    Twitter, Inc. (NYSE:TWTR) Q3 2019 Results Earn...            Operator
# 21    General Motors Company (NYSE:GM) Q3 2019 Earni...  Dhivya Suryadevara
# 22    Starbucks Corporation (NASDAQ:SBUX) Q4 2019 Ea
# 27                  answer
# 28    operator_instruction
# 29                question
# ...                    ...
# 2971              question
# 2972                answer
# 2973                answer
# 2974                answer
# 2975          presentation
# 2976          presentation
# 2977                answer
# 2978                answer
# 2979              question
# 2980              question
# 2981                answer
# 2982              question
# 2983                answer
# 2984          presentation
# 2985                answer
# 2986          presentation
# 2987                answer
# 2988                answer
# 2989                answer
# 2990                answer
# 2991          presentation
# 2992                answer
# 2993                answer
# 2994                answer
# 2995          presentation
# 2996              question
# 2997              question
# 2998          presentation
# 2999                answer
# 3000                answer
#
# [3001 rows x 8 columns]

# %%
doca = dataset1[3]
doca
# Out:
# 0                                                sentence
# 1       Patrik's proven command of this business and t...
# 2       We will be at the Jefferies conference, hardwa...
# 3                                [Operator Instructions].
# 4       Any update that you can share in terms of mile...
# 5       With that, let me turn to the outlook for the ...
# 6                                        Hope that helps.
# 7       Since you're probably wondering and we've talk...
# 8       Good morning and welcome to GE's third quarter...
# 9       There's no other like one time item or whateve...
# 10      We started putting that cash to work, with a $...
# 11      I’m pleased to announce that carne asada is th...
# 12      We have 30.2 million digital active customers ...
# 13      So, I think what you see a little bit relative...
# 14      I think it is very hard to provide guidance on...
# 15                    And I believe that we started that.
# 16       And then on carne asada, if you could help qu...
# 17      So the focus that we've put on the customer ex...
# 18      Mortgage originations increased $5 billion fro...
# 19                            Well, that is Customer 360.
# 20       Our next question comes from the line of Bria...
# 21      From a raw material and tariff perspective to ...
# 22                    We now cover 80% of our store base.
# 23      And don't underestimate the work that we've be...
# 24      Can you put the more detail what you thinking ...
# 25      Additionally, with the lap of the leadership c...
# 26      It's tough getting to $5 billion, I'll tell yo...
# 27      But September was an especially strong month f...
# 28                                     Your line is open.
# 29                            Thanks for all the details.
#                               ...
# 2971    There's other lesser enduring brands that kind...
# 2972    And what we've seen in the second half and we'...
# 2973                                          Absolutely.
# 2974    Now I think your point, admittedly a 20 basis ...
# 2975    Progress payments were a usage of gas as expec...
# 2976    Our light duty pickup trucks improved 6.8% at ...
# 2977    And in Q3, I'd say rather that we go through a...
# 2978    So from there we're really wrestling with the ...
# 2979    Obviously Nitro is relatively new across the s...
# 2980    But I wonder if you might comment on if you’ve...
# 2981    And we're very encouraged by what's happening ...
# 2982                                      Good afternoon.
# 2983    And I think, what we just wanted to share with...
# 2984    Moving to pro visualization, revenue reached $...
# 2985    Some – there's all sorts of efficiencies that ...
# 2986    This test tends to be predictive of what happe...
# 2987    And Turing is the world’s first DXR, the first...
# 2988    So, when we think about other brands that are ...
# 2989    We're seeing very good strong growth and uptic...
# 2990    So that's not been a problem to-date and it's ...
# 2991    Aviation is negatively impacted by the MAX gro...
# 2992    Really repositioning our business, restructuri...
# 2993               the segment share within the industry.
# 2994     Yes, so my expectation is that deposit costs ...
# 2995    This is industry-leading domestic growth for a...
# 2996    With 7 million loyalty members now, can you ta...
# 2997                                           Thank you.
# 2998                                Turning to cash flow.
# 2999    That, plus the working capital unwind, constit...
# 3000                          Look, it’s a good question.
# Name: 3, Length: 3001, dtype: object

# %%
tfidf = TfidfVectorizer()

# %%
response = tfidf.fit_transform(doca)

# %%
kmeans = KMeans(n_clusters=10).fit(response)

# %%
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
lines_for_predicting = ["Mike is awesome!", "some androids is there in the brain"]
kmeans.predict(tfidf.transform(lines_for_predicting))
# Out:
# array([1, 1])
