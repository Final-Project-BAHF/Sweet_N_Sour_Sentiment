# %% [markdown]
# # Sweet n Sour Sentiment on the Street
# Georgia Tech Data Science Bootcamp - Cohort 6
# Final Project
# Team Members:
# * Joseph Ayala
# * Andrew Behrman
# * Michael Fox
# * Michael Hankinson
#
# ### 3rd Party Sentiments
#
# #### This notebook is designed to iterate through the tabular call transcript data previously parsed and assign sentiment scores to each sentence using Google NLP and Vader Sentiment Analysis

# %%
import pandas as pd

# %%
# import SentimentIntensityAnalyzer class 
# from vaderSentiment.vaderSentiment module. 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
  
# function to print sentiments 
# of the sentence. 
def sentiment_scores(sentence): 
  
    # Create a SentimentIntensityAnalyzer object. 
    sid_obj = SentimentIntensityAnalyzer() 
  
    # polarity_scores method of SentimentIntensityAnalyzer 
    # oject gives a sentiment dictionary. 
    # which contains pos, neg, neu, and compound scores. 
    sentiment_dict = sid_obj.polarity_scores(sentence) 

#     print("Overall sentiment dictionary is : ", sentiment_dict) 
#     print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative") 
#     print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral") 
#     print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive") 
  
#     print("Sentence Overall Rated As", end = " ") 
  
#     # decide sentiment as positive, negative and neutral 
#     if sentiment_dict['compound'] >= 0.05 : 
#         print("Positive") 
  
#     elif sentiment_dict['compound'] <= - 0.05 : 
#         print("Negative") 
  
#     else : 
#         print("Neutral") 

    return sentiment_dict

# %%
# read in tabular transcript data
df_transcripts = pd.read_csv('./sentences_all.txt',sep='|')
df_transcripts.head()
# Out:
#    id  sentiment                                           sentence ticker  \
# 0   0        NaN   Good afternoon and welcome to the Chipotle Me...    CMG
# 1   1        NaN    All participants will be in a listen-only mode.    CMG
# 2   2        NaN  [Operator Instructions] After today’s presenta...    CMG
# 3   3        NaN  [Operator Instructions] Please note this event...    CMG
# 4   4        NaN  I would now like to turn the conference over t...    CMG
#
#                                           call_title   speaker  \
# 0  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 1  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 2  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 3  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 4  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
#
#            call_section
# 0  operator_instruction
# 1  operator_instruction
# 2  operator_instruction
# 3  operator_instruction
# 4  operator_instruction

# %%
# add new vader_sentiment column

df_transcripts['vader_sentiment'] = df_transcripts['sentence'].apply(lambda x: sentiment_scores(x)['compound'])
df_transcripts
# Out:
#         id  sentiment                                           sentence  \
# 0        0        NaN   Good afternoon and welcome to the Chipotle Me...
# 1        1        NaN    All participants will be in a listen-only mode.
# 2        2        NaN  [Operator Instructions] After today’s presenta...
# 3        3        NaN  [Operator Instructions] Please note this event...
# 4        4        NaN  I would now like to turn the conference over t...
# ...    ...        ...                                                ...
# 5158  5158        NaN                           Best regards to you all.
# 5159  5159        NaN                                         Take care.
# 5160  5160        NaN   Ladies and gentlemen, this concludes today's ...
# 5161  5161        NaN                         Thank you all for joining.
# 5162  5162        NaN                            You may now disconnect.
#
#      ticker                                         call_title       speaker  \
# 0       CMG  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...      Operator
# 1       CMG  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...      Operator
# 2       CMG  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...      Operator
# 3       CMG  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...      Operator
# 4       CMG  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...      Operator
# ...     ...                                                ...           ...
# 5158    WFC  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...  Allen Parker
# 5159    WFC  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...  Allen Parker
# 5160    WFC  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...      Operator
# 5161    WFC  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...      Operator
# 5162    WFC  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...      Operator
#
#               call_section  vader_sentiment
# 0     operator_instruction           0.7096
# 1     operator_instruction           0.0000
# 2     operator_instruction           0.4215
# 3     operator_instruction           0.3182
# 4     operator_instruction           0.3612
# ...                    ...              ...
# 5158          presentation           0.6369
# 5159          presentation           0.4939
# 5160  operator_instruction           0.0000
# 5161  operator_instruction           0.3612
# 5162  operator_instruction           0.0000
#
# [5163 rows x 8 columns]

# %%
# save results
df_transcripts.to_csv('./sentences_all_vader.txt',sep='|')

# %%
df_big = pd.read_csv('./hundred_sentences_all_vader.txt',sep='|')
df_big.drop(columns="Unnamed: 0",inplace=True)
df_big.head()
# Out:
#    id  sentiment                                           sentence ticker  \
# 0   0        NaN   Good evening, this is Michael Partridge, Seni...   VRTX
# 1   1        NaN  Tonight, we will review with you Vertex's busi...   VRTX
# 2   2        NaN  Making prepared remarks on the call tonight, w...   VRTX
# 3   3        NaN  We recommend that you access the webcast slide...   VRTX
# 4   4        NaN  This conference call is being recorded and a r...   VRTX
#
#                                           call_title            speaker  \
# 0  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 1  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 2  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 3  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 4  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
#
#    call_section  vader_sentiment
# 0  presentation           0.4404
# 1  presentation           0.4215
# 2  presentation           0.2263
# 3  presentation           0.3612
# 4  presentation           0.0000

# %%
df_big.count()
# Out:
# id                 45876
# sentiment              0
# sentence           45876
# ticker             45876
# call_title         45876
# speaker            45876
# call_section       45876
# vader_sentiment    45876
# dtype: int64

# %%
df_transcripts.head()
# Out:
#    id  sentiment                                           sentence ticker  \
# 0   0        NaN   Good afternoon and welcome to the Chipotle Me...    CMG
# 1   1        NaN    All participants will be in a listen-only mode.    CMG
# 2   2        NaN  [Operator Instructions] After today’s presenta...    CMG
# 3   3        NaN  [Operator Instructions] Please note this event...    CMG
# 4   4        NaN  I would now like to turn the conference over t...    CMG
#
#                                           call_title   speaker  \
# 0  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 1  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 2  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 3  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 4  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
#
#            call_section  vader_sentiment
# 0  operator_instruction           0.7096
# 1  operator_instruction           0.0000
# 2  operator_instruction           0.4215
# 3  operator_instruction           0.3182
# 4  operator_instruction           0.3612

# %%
df_transcripts.count()
# Out:
# id                 5163
# sentiment             0
# sentence           5163
# ticker             5163
# call_title         5163
# speaker            5163
# call_section       5163
# vader_sentiment    5163
# dtype: int64

# %%
df_big = df_big.append(df_transcripts)
df_big.count()
# Out:
# id                 51039
# sentiment              0
# sentence           51039
# ticker             51039
# call_title         51039
# speaker            51039
# call_section       51039
# vader_sentiment    51039
# dtype: int64

# %%
df_big.head()
# Out:
#    id  sentiment                                           sentence ticker  \
# 0   0        NaN   Good evening, this is Michael Partridge, Seni...   VRTX
# 1   1        NaN  Tonight, we will review with you Vertex's busi...   VRTX
# 2   2        NaN  Making prepared remarks on the call tonight, w...   VRTX
# 3   3        NaN  We recommend that you access the webcast slide...   VRTX
# 4   4        NaN  This conference call is being recorded and a r...   VRTX
#
#                                           call_title            speaker  \
# 0  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 1  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 2  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 3  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
# 4  Vertex Pharmaceuticals Incorporated (NASDAQ:VR...  Michael Partridge
#
#    call_section  vader_sentiment
# 0  presentation           0.4404
# 1  presentation           0.4215
# 2  presentation           0.2263
# 3  presentation           0.3612
# 4  presentation           0.0000

# %%
df_big.to_csv('./complete_vader.txt',sep='|')
