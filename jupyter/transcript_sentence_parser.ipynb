# %% [markdown]
# # Sweet n Sour Sentiment on the Street
# Georgia Tech Data Science Bootcamp - Cohort 6
# Final Project
# Team Members:
# * Joseph Ayala
# * Andrew Behrman
# * Michael Fox
# * Michael Hankinson
#
# ### Transcript Sentence Parser
#
# #### This notebook is designed to iterate through the call transcripts found in a MongoDb and parse the paragraphs into sentences.

# %%
import pymongo

# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database
db = client.sweet_n_sour

# %%
# get list of transcripts
calls = db.call_transcripts.find()

# %%
from nltk.tokenize import sent_tokenize
import pandas as pd
import itertools
int_id = itertools.count(0)

# initialize dataframe to collect output
df_sentences = pd.DataFrame()

# iterate through each transcript record
for call in calls:
    print(f'\n**** {call["ticker"]} ****')
    
    # iterate through each paragraph in the transcript
    for p in call['paragraphs']:
          
        # parse paragraph into sentences
        arr_sentences = sent_tokenize(p['content'])
          
        # iterate through each sentence
        sentence_collection = [{
              'id': next(int_id),
              'sentiment': '',
              'sentence': s,
              'ticker': call['ticker'],
              'call_title': call['call_title'],
              'speaker': p['speaker'],
              'call_section': p['call_section']
        } for s in arr_sentences]
          
        # append paragrah's sentences to dataframe
        df_sentences = df_sentences.append(pd.DataFrame(sentence_collection))

df_sentences.head()
# Out:
# **** CMG ****
#
# **** CRM ****
#
# **** GE ****
#
# **** GM ****
#
# **** IVZ ****
#
# **** NVDA ****
#
# **** SBUX ****
#
# **** TWTR ****
#
# **** UAA ****
#
# **** WFC ****
#    id sentiment                                           sentence ticker  \
# 0   0             Good afternoon and welcome to the Chipotle Me...    CMG
# 1   1              All participants will be in a listen-only mode.    CMG
# 2   2            [Operator Instructions] After today’s presenta...    CMG
# 3   3            [Operator Instructions] Please note this event...    CMG
# 4   4            I would now like to turn the conference over t...    CMG
#
#                                           call_title   speaker  \
# 0  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 1  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 2  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 3  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
# 4  Chipotle Mexican Grill, Inc. (NYSE:CMG) Q3 201...  Operator
#
#            call_section
# 0  operator_instruction
# 1  operator_instruction
# 2  operator_instruction
# 3  operator_instruction
# 4  operator_instruction

# %%
df_sentences.tail()
# Out:
#      id sentiment                                           sentence ticker  \
# 2  5158                                     Best regards to you all.    WFC
# 3  5159                                                   Take care.    WFC
# 0  5160             Ladies and gentlemen, this concludes today's ...    WFC
# 1  5161                                   Thank you all for joining.    WFC
# 2  5162                                      You may now disconnect.    WFC
#
#                                           call_title       speaker  \
# 2  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...  Allen Parker
# 3  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...  Allen Parker
# 0  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...      Operator
# 1  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...      Operator
# 2  Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...      Operator
#
#            call_section
# 2          presentation
# 3          presentation
# 0  operator_instruction
# 1  operator_instruction
# 2  operator_instruction

# %% [markdown]
# #### Write dataframe out to csv

# %%
# First output entire collection
outfile = '../data/sentences_all.txt'
df_sentences.to_csv(outfile, sep='|',index=False)

# %%
# get random sample of 3000 sentences with repeatable results

df_sample_sentences = df_sentences.sample(n=3000,random_state=1)

# check sample size
print(f'Selected {len(df_sample_sentences)} sample sentences.')

# output sample sentences to file
sample_outfile = '../data/sentences_sample.txt'
df_sample_sentences.to_csv(sample_outfile, sep='|', index=False)
# Out:
# Selected 3000 sample sentences.
