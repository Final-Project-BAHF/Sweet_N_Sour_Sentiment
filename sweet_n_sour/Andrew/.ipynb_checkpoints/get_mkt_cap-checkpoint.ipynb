# %%
# Dependencies
import pandas as pd
import pandas_datareader as web
import datetime

# %%
ticker_set_df = pd.read_csv('../../db/hundred_addl_stocks.csv',sep=',')
ticker_set_df.head()
tickers = ticker_set_df['0'].tolist()
new_tickers = ['IVZ','GM','UAA','WFC','TWTR','SBUX','CRM','AMZN','GE','CMG']
tickers = tickers + new_tickers
tickers.remove('APC')
tickers.remove('DWDP')
tickers.remove('TMK')


tickers
# Out:
# ['VRTX',
#  'D',
#  'WELL',
#  'ORCL',
#  'NTRS',
#  'RCL',
#  'REG',
#  'EQT',
#  'CFG',
#  'TSN',
#  'DVA',
#  'EVHC',
#  'CRM',
#  'MMC',
#  'BF.B',
#  'UNM',
#  'ADM',
#  'ETR',
#  'SCG',
#  'PX',
#  'GLW',
#  'BKNG',
#  'ROP',
#  'UDR',
#  'MDT',
#  'MSI',
#  'CBRE',
#  'NFLX',
#  'MLM',
#  'ANDV',
#  'AIZ',
#  'CMI',
#  'COF',
#  'IP',
#  'DE',
#  'KMX',
#  'SEE',
#  'SBUX',
#  'HRL',
#  'JNPR',
#  'AAP',
#  'AEE',
#  'ABT',
#  'MTD',
#  'TRV',
#  'BDX',
#  'PNR',
#  'LYB',
#  'JBHT',
#  'MO',
#  'INCY',
#  'SRCL',
#  'RTN',
#  'AMG',
#  'CCI',
#  'NRG',
#  'VMC',
#  'ESRX',
#  'AMT',
#  'LNC',
#  'XLNX',
#  'CL',
#  'ABBV',
#  'CLX',
#  'XEL',
#  'CMG',
#  'PFG',
#  'FOX',
#  'DUK',
#  'MA',
#  'MOS',
#  'HSIC',
#  'EOG',
#  'WMT',
#  'VAR',
#  'MET',
#  'CAG',
#  'ACN',
#  'DVN',
#  'VTR',
#  'NEM',
#  'NFX',
#  'BAC',
#  'CINF',
#  'MTB',
#  'AVB',
#  'VRSN',
#  'CNP',
#  'KSS',
#  'TWX',
#  'AMAT',
#  'NOV',
#  'LLY',
#  'M',
#  'MAR',
#  'ALK',
#  'PRU',
#  'IVZ',
#  'GM',
#  'UAA',
#  'WFC',
#  'TWTR',
#  'SBUX',
#  'CRM',
#  'AMZN',
#  'GE',
#  'CMG']

# %%
start = datetime.datetime(2019, 1, 1)
end = datetime.datetime(2019, 11, 14)
df_output = pd.DataFrame()
for ticker in tickers:
    try:
        mydata = web.get_quote_yahoo(ticker)['marketCap']
        df = pd.DataFrame(mydata)
        df['ticker'] = ticker
        df_output = df_output.append(df)
    except KeyError:
        pass
df_output
# Out:
#          marketCap ticker
# VRTX   53950070784   VRTX
# D      67584167936      D
# WELL   34083141632   WELL
# ORCL  185199771648   ORCL
# NTRS   22576027648   NTRS
# RCL    24713400320    RCL
# REG    10953659392    REG
# EQT     2645905152    EQT
# CFG    16519322624    CFG
# TSN    32988065792    TSN
# DVA     9179922432    DVA
# CRM   143135178752    CRM
# MMC    53242474496    MMC
# UNM     6126159872    UNM
# ADM    23865128960    ADM
# ETR    23237193728    ETR
# GLW    22573379584    GLW
# BKNG   77383655424   BKNG
# ROP    35966607360    ROP
# UDR    14195486720    UDR
# MDT   150347546624    MDT
# MSI    27770138624    MSI
# CBRE   18893402112   CBRE
# NFLX  129297195008   NFLX
# MLM    16277004288    MLM
# AIZ     8009382400    AIZ
# CMI    28189536256    CMI
# COF    45351907328    COF
# IP     17900095488     IP
# DE     54939037696     DE
# ...            ...    ...
# MET    45310218240    MET
# CAG    14020501504    CAG
# ACN   125163880448    ACN
# DVN     8665295872    DVN
# VTR    21730508800    VTR
# NEM    30834145280    NEM
# BAC   296208957440    BAC
# CINF   17497354240   CINF
# MTB    21637480448    MTB
# AVB    29961689088    AVB
# VRSN   21702838272   VRSN
# CNP    12797125632    CNP
# KSS     9401224192    KSS
# AMAT   57328173056   AMAT
# NOV     8596337664    NOV
# LLY   108677234688    LLY
# M       5205217792      M
# MAR    44306501632    MAR
# ALK     8668915712    ALK
# PRU    37647302656    PRU
# IVZ     7920451072    IVZ
# GM     52707692544     GM
# UAA     7662259712    UAA
# WFC   227539566592    WFC
# TWTR   22708441088   TWTR
# SBUX   99755171840   SBUX
# CRM   143135178752    CRM
# AMZN  862433902592   AMZN
# GE    100610498560     GE
# CMG    20975925248    CMG
#
# [99 rows x 2 columns]

# %%
df_output.to_csv('../../db/ticker_mktCap_test.csv', sep=',')
