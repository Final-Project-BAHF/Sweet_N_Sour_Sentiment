# %%
# Dependencies
import pandas as pd
import pandas_datareader as web
import datetime

# %%
ticker_set_df = pd.read_csv('../../db/hundred_addl_stocks.csv',sep=',')
ticker_set_df.head()
tickers = ticker_set_df['0'].tolist()
new_tickers = ['IVZ','GM','UAA','WFC','TWTR','SBUX','CRM','AMZN','GE','CMG']
tickers = tickers + new_tickers
tickers.remove('APC')
tickers.remove('DWDP')
tickers.remove('TMK')


tickers
# Out:
# ['VRTX',
#  'D',
#  'WELL',
#  'ORCL',
#  'NTRS',
#  'RCL',
#  'REG',
#  'EQT',
#  'CFG',
#  'TSN',
#  'DVA',
#  'EVHC',
#  'CRM',
#  'MMC',
#  'BF.B',
#  'UNM',
#  'ADM',
#  'ETR',
#  'SCG',
#  'PX',
#  'GLW',
#  'BKNG',
#  'ROP',
#  'UDR',
#  'MDT',
#  'MSI',
#  'CBRE',
#  'NFLX',
#  'MLM',
#  'ANDV',
#  'AIZ',
#  'CMI',
#  'COF',
#  'IP',
#  'DE',
#  'KMX',
#  'SEE',
#  'SBUX',
#  'HRL',
#  'JNPR',
#  'AAP',
#  'AEE',
#  'ABT',
#  'MTD',
#  'TRV',
#  'BDX',
#  'PNR',
#  'LYB',
#  'JBHT',
#  'MO',
#  'INCY',
#  'SRCL',
#  'RTN',
#  'AMG',
#  'CCI',
#  'NRG',
#  'VMC',
#  'ESRX',
#  'AMT',
#  'LNC',
#  'XLNX',
#  'CL',
#  'ABBV',
#  'CLX',
#  'XEL',
#  'CMG',
#  'PFG',
#  'FOX',
#  'DUK',
#  'MA',
#  'MOS',
#  'HSIC',
#  'EOG',
#  'WMT',
#  'VAR',
#  'MET',
#  'CAG',
#  'ACN',
#  'DVN',
#  'VTR',
#  'NEM',
#  'NFX',
#  'BAC',
#  'CINF',
#  'MTB',
#  'AVB',
#  'VRSN',
#  'CNP',
#  'KSS',
#  'TWX',
#  'AMAT',
#  'NOV',
#  'LLY',
#  'M',
#  'MAR',
#  'ALK',
#  'PRU',
#  'IVZ',
#  'GM',
#  'UAA',
#  'WFC',
#  'TWTR',
#  'SBUX',
#  'CRM',
#  'AMZN',
#  'GE',
#  'CMG']

# %%
start = datetime.datetime(2019, 1, 1)
end = datetime.datetime(2019, 11, 14)
df_output = pd.DataFrame()
for ticker in tickers:
    try:
        mydata = web.DataReader(ticker, 'yahoo', start, end)
        df = pd.DataFrame(mydata)
        df['ticker'] = ticker
        df_output = df_output.append(df)
    except KeyError:
        pass
df_output
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-01-02  165.139999  160.949997  161.210007  164.080002  1465400.0
# 2019-01-03  169.320007  163.179993  165.830002  163.729996  1690900.0
# 2019-01-04  173.309998  164.899994  165.899994  172.699997  1874500.0
# 2019-01-07  176.779999  170.869995  173.050003  175.850006  1294600.0
# 2019-01-08  178.410004  174.720001  177.000000  178.190002  1653200.0
# 2019-01-09  182.699997  178.250000  179.139999  182.300003  2298500.0
# 2019-01-10  186.089996  180.259995  181.850006  186.029999  1988200.0
# 2019-01-11  188.860001  183.429993  184.619995  188.160004  2222600.0
# 2019-11-05  751.609985  733.520020  750.000000  740.760010   802600.0
# 2019-11-06  750.739990  740.799988  742.330017  744.309998   380800.0
# 2019-11-07  746.580017  734.109985  745.000000  737.340027   478800.0
# 2019-11-08  744.659973  730.500000  736.000000  731.619995   529300.0
# 2019-11-11  745.869995  728.000000  728.690002  743.369995   581400.0
# 2019-11-12  764.789978  755.059998  757.989990  757.270020   664900.0
# 2019-11-13  757.510010  747.210022  754.119995  753.299988   457000.0
# 2019-11-14  755.840027  743.609985  755.000000  749.200012   423600.0
# 2019-11-15  754.849976  746.729980  749.299988  754.659973   313700.0
#
#              Adj Close ticker
# Date
# 2019-01-02  164.080002   VRTX
# 2019-01-03  163.729996   VRTX
# 2019-01-04  172.699997   VRTX
# 2019-01-07  175.850006   VRTX
# 2019-01-08  178.190002   VRTX
# 2019-01-09  182.300003   VRTX
# 2019-01-10  186.029999   VRTX
# 2019-01-11  188.160004   VRTX
# 2019-01-14  183.910004   VRTX
# 2019-01-15  186.679993   VRTX
# 2019-01-16  186.149994   VRTX
# 2019-01-17  190.520004   VRTX
# 2019-01-18  194.699997   VRTX
# 2019-01-22  193.880005   VRTX
# 2019-01-23  189.889999   VRTX
# 2019-01-24  186.580002   VRTX
# 2019-01-25  189.500000   VRTX
# 2019-01-28  188.089996   VRTX
# 2019-01-29  186.380005   VRTX
# 2019-01-30  187.050003   VRTX
# 2019-01-31  190.910004   VRTX
# 2019-02-01  191.520004   VRTX
# 2019-02-04  187.979996   VRTX
# 2019-02-05  187.020004   VRTX
# 2019-02-06  182.389999   VRTX
# 2019-02-07  180.179993   VRTX
# 2019-02-08  181.339996   VRTX
# 2019-02-11  181.529999   VRTX
# 2019-02-12  184.009995   VRTX
# 2019-02-13  185.250000   VRTX
# ...                ...    ...
# 2019-10-07  814.159973    CMG
# 2019-10-08  805.880005    CMG
# 2019-10-09  827.289978    CMG
# 2019-10-10  827.750000    CMG
# 2019-10-11  830.349976    CMG
# 2019-10-14  828.130005    CMG
# 2019-10-15  826.739990    CMG
# 2019-10-16  823.250000    CMG
# 2019-10-17  829.070007    CMG
# 2019-10-18  841.479980    CMG
# 2019-10-21  851.539978    CMG
# 2019-10-22  831.070007    CMG
# 2019-10-23  788.190002    CMG
# 2019-10-24  798.340027    CMG
# 2019-10-25  787.869995    CMG
# 2019-10-28  782.609985    CMG
# 2019-10-29  763.820007    CMG
# 2019-10-30  775.520020    CMG
# 2019-10-31  778.159973    CMG
# 2019-11-01  768.630005    CMG
# 2019-11-04  751.770020    CMG
# 2019-11-05  740.760010    CMG
# 2019-11-06  744.309998    CMG
# 2019-11-07  737.340027    CMG
# 2019-11-08  731.619995    CMG
# 2019-11-11  743.369995    CMG
# 2019-11-12  757.270020    CMG
# 2019-11-13  753.299988    CMG
# 2019-11-14  749.200012    CMG
# 2019-11-15  754.659973    CMG
#
# [22186 rows x 7 columns]

# %%
df_output.to_csv('../../db/ticker_closing_prices.csv', sep=',')
