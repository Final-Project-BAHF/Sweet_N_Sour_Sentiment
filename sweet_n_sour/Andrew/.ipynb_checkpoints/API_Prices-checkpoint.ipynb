# %%
# Dependencies
import requests
import json
import quandl
import pandas as pd
from config import price_key

# %%
# URL for GET requests to retrieve vehicle data
tickers = ['IVZ','GM','UAA''WFC','TWTR','SBUX','CRM','AMZN','GE','CMG']
mydata = GET https://api.worldtradingdata.com/api/v1/history?symbol=tickers&sort=newest&api_token=price_key
# Out:
#   File "<ipython-input-4-81765e43d6b4>", line 3
#     mydate = GET https://api.worldtradingdata.com/api/v1/history?symbol=tickers&sort=newest&api_token=price_key
#                      ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame(mydata)
mydata
# Out:
#      ticker       date    close      volume
# None
# 0      TWTR 2018-03-27    28.07  79821992.0
# 1      TWTR 2018-03-26    31.91  25477813.0
# 2      TWTR 2018-03-23    31.03  24478532.0
# 3      TWTR 2018-03-22    31.20  29284239.0
# 4      TWTR 2018-03-21    32.73  43359002.0
# 5      TWTR 2018-03-20    31.35  82222740.0
# 6      TWTR 2018-03-19    34.98  22116551.0
# 7      TWTR 2018-03-16    35.58  13747877.0
# 8      TWTR 2018-03-15    35.80  20921849.0
# 9      TWTR 2018-03-14    36.60  39409327.0
# 10     TWTR 2018-03-13    34.11  21967251.0
# 11     TWTR 2018-03-12    35.50  20963776.0
# 12     TWTR 2018-03-09    35.35  18513795.0
# 13     TWTR 2018-03-08    34.85  24764968.0
# 14     TWTR 2018-03-07    35.76  33656143.0
# 15     TWTR 2018-03-06    34.43  22592276.0
# 16     TWTR 2018-03-05    34.58  34839998.0
# 17     TWTR 2018-03-02    33.00  24918891.0
# 18     TWTR 2018-03-01    32.24  25032477.0
# 19     TWTR 2018-02-28    31.86  24101591.0
# ...

# %%
df.to_csv('../../db/ticker_closing_prices.csv', sep=',')
