# %%
# Dependencies
import requests
import json
import quandl
import pandas as pd
from config import qkey

# %%
# URL for GET requests to retrieve vehicle data
quandl.ApiConfig.api_key = qkey
tickers = ['IVZ','GM','UAA''WFC','TWTR','SBUX','CRM','AMZN','GE','CMG']
mydata = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'close'] }, ticker = tickers, date = { 'gte': '2018-01-01', 'lte': '2019-11-10' })

# %%
df = pd.DataFrame(mydata)
mydata
# Out:
#      ticker       date    close
# None
# 0      TWTR 2018-03-27    28.07
# 1      TWTR 2018-03-26    31.91
# 2      TWTR 2018-03-23    31.03
# 3      TWTR 2018-03-22    31.20
# 4      TWTR 2018-03-21    32.73
# 5      TWTR 2018-03-20    31.35
# 6      TWTR 2018-03-19    34.98
# 7      TWTR 2018-03-16    35.58
# 8      TWTR 2018-03-15    35.80
# 9      TWTR 2018-03-14    36.60
# 10     TWTR 2018-03-13    34.11
# 11     TWTR 2018-03-12    35.50
# 12     TWTR 2018-03-09    35.35
# 13     TWTR 2018-03-08    34.85
# 14     TWTR 2018-03-07    35.76
# 15     TWTR 2018-03-06    34.43
# 16     TWTR 2018-03-05    34.58
# 17     TWTR 2018-03-02    33.00
# 18     TWTR 2018-03-01    32.24
# 19     TWTR 2018-02-28    31.86
# 20     TWTR 2018-02-27    31.32
# 21     TWTR 2018-02-26    32.16
# 22     TWTR 2018-02-23    32.66
# 23     TWTR 2018-02-22    32.11
# 24     TWTR 2018-02-21    33.38
# 25     TWTR 2018-02-20    32.84
# 26     TWTR 2018-02-16    33.06
# 27     TWTR 2018-02-15    33.61
# ...

# %%
df.to_csv('ticker_closing_prices.csv', sep=',')
